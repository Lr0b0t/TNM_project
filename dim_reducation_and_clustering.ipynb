# %%
using AutoEncoderToolkit
using AutoEncoderToolkit.VAEs
using Clustering                
using Combinatorics
using CUDA
using CSV
using DataFrames
using DelimitedFiles
using Distributions
using Distances
using FileIO
using Flux
using GaussianMixtures         
using Glob
using LinearAlgebra
using MAT                      
using Measures
using MultivariateStats         
using NIfTI
using Plots
using Printf
using Random
using RegressionDynamicCausalModeling
using Statistics
using StatsBase                
using TSne
using MultivariateStats: PCA, fit, transform


include("utils.jl")
include("utils_clustering.jl")

const FUNC_DIR = "data/FunImgARCFW_n88"
const RESULTS_DIR = "data/connectivity_n88"
const ATLAS_DIR = "data"
const FUNC_FILENAME = "wFiltered_4DVolume.nii"
const ATLAS_FILENAME = "BN_Atlas_246_3mm.nii"
const BNA_MATRIX_FILENAME = "data/BNA_matrix_binary_246x246.csv"
const SUBDIAGNOSIS_CSV_FILENAME = "data/sub_diagnosis_n88.csv"
# Out:
# "data/sub_diagnosis_n88.csv"

# %% [markdown]
# 1) Load Connectivity Data
# Load both rDCM and functional connectivity results from previously saved `.mat` files.
#
# This loads for each subject:
# - connectivity_data["<subject_id>"]["rdcm"]
# - connectivity_data["<subject_id>"]["fc_mat"]
# - connectivity_data["<subject_id>"]["fc_z"]
# - connectivity_data["<subject_id>"]["cov_mat"]

# %%
connectivity_data = load_connectivity_data(RESULTS_DIR; load_rdcm=true, load_functional=true)

# %% [markdown]
# 2) Mask and Flatten Matrices and Build Matrices for Analysis
#  Apply the structural mask (BNA matrix) and flatten the connectivity matrices into vectors:
#
# These are stored as nested dictionaries where:
# - Keys are subject IDs,
# - Values are vectors of connectivity values.
#
#
# Transform connectivity vectors into subject × feature matrices.
# You can also extract specific types like functional connectivity.

# %%
masked_connectivity_vectors = mask_and_flatten_connectivity_data(connectivity_data, BNA_MATRIX_FILENAME; mask=true)
connectivity_vectors = mask_and_flatten_connectivity_data(connectivity_data, BNA_MATRIX_FILENAME; mask=false)
subjectIDs =  extract_allSubjectIDs(RESULTS_DIR)


masked_connectivity_matrix = get_connectivity_matrix(masked_connectivity_vectors, subjectIDs)
connectivity_matrix = get_connectivity_matrix(connectivity_vectors, subjectIDs )
matrix_fc = get_connectivity_matrix(connectivity_vectors, subjectIDs, "fc_mat")
matrix_masked_fc = get_connectivity_matrix(masked_connectivity_vectors, subjectIDs, "fc_mat")
# Out:
# 88×11060 Matrix{Float64}:
#  0.45254    0.582365   0.263348   …  -0.149657     0.169509   0.44305
#  0.667324   0.61458    0.441389       0.0850222    0.0530302  0.543824
#  0.454203   0.523889   0.317798       0.248442     0.58188    0.59517
#  0.88403    0.105796   0.0389225      0.406011     0.174374   0.791872
#  0.641462   0.38131    0.0934279      0.627856     0.363746   0.752038
#  0.613588   0.110665  -0.0169369  …   0.231938     0.342462   0.896338
#  0.954613   0.826107   0.829335       0.584308     0.344539   0.845087
#  0.73033   -0.104463  -0.0800406      0.00623737  -0.0225886  0.66911
#  0.573449   0.316101   0.263258       0.506535     0.575842   0.775527
#  0.540277   0.36996    0.816273       0.722109     0.703819   0.445008
#  ⋮                                ⋱
#  0.424387   0.495474   0.484028       0.179833     0.0476406  0.5422
#  0.545267   0.718087   0.625973   …   0.423885     0.0974599  0.537257
#  0.744607   0.477448   0.618623       0.16184      0.224431   0.796984
#  0.784217   0.619431   0.356629       0.178703     0.0717614  0.780649
#  0.511432   0.311027   0.280697       0.676012     0.752697   0.690145
#  0.80821    0.45854    0.483476       0.416267     0.409125   0.526816
#  0.819586   0.414015   0.600578   …   0.651613     0.387537   0.617704
#  0.836045   0.299791   0.310127       0.378479     0.208321   0.803958
#  0.649699   0.481411   0.67975        0.518906     0.58908    0.721284

# %% [markdown]
# 3) Load Group Labels
#
# Load subject diagnostic labels from a CSV file:

# %%
# Load CSV and skip the first row
data_table = CSV.read(SUBDIAGNOSIS_CSV_FILENAME, DataFrame; delim=',', skipto=2)
# Extract the 'group_1till5' column and convert to Int
group_col = data_table[!, Symbol("group [1-4, 4=NC, 3=PTSD+TBI, 2=PTSD, 1=TBI]")]
group_array = convert(Vector{Int}, group_col)  # convert to a plain array of Ints
# Out:
# 88-element Vector{Int64}:
#  3
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  2
#  ⋮
#  2
#  4
#  1
#  4
#  1
#  1
#  1
#  4
#  4

# %% [markdown]
# The following parameters are defined  to control dimensionality reduction and clustering analysis:
#
# - `dims_list`: Latent dimensions to evaluate → [2, 10, 20, 50, 100]
#
# - `data_sources`: Connectivity data used for training:
#     - "RDCM" → rDCM-based connectivity
#     - "FC"   → functional connectivity (masked)
#
# - `methods`: Dimensionality reduction methods to compare:
#     - "PCA"
#     - "tSNE"
#     - "VAE"
#
# - `clustering_methods`: Clustering algorithms applied in the reduced space:
#     - "kmeans"
#     - "fuzzy"
#     - "hierarchical"
#
# - `repeats`: Number of repetitions per method and configuration → 1

# %%
dims_list= [2, 10, 20, 50, 100]
data_sources = Dict("RDCM" => connectivity_matrix, "FC" => matrix_masked_fc)
methods = ["PCA", "tSNE", "VAE"]
repeats = 50
clustering_methods = ["kmeans", "fuzzy","hierarchical"]
select_counts = [20, 20, 0, 20] # how many subjects are selected from each of four groups
# Out:
# 4-element Vector{Int64}:
#  20
#  20
#   0
#  20

# %% [markdown]
# Training VAE for specified latent dimensions in dims_list_dimExp

# %%
# Dictionary to store all trained models and their metrics
vae_results = Dict()
n_epochs = 30

# Loop over datasets and latent dimensions
for (data_name, matrix) in data_sources
    println("Training on dataset: $data_name")

    dataset_results = Dict()
    matrix_f32 = Float32.((matrix))

    for dim in dims_list
        println("  Latent Dim: $dim")

        # Train the model
        vae_model, metrics = train_vae_model(matrix_f32, dim, n_epochs)

        # Save model and metrics
        dataset_results[string(dim)] = (
            model = vae_model,
            metrics = metrics,
        )
    end

    vae_results[data_name] = dataset_results
end
# Out:
# Training on dataset: RDCM
#   Latent Dim: 2
# Using GPU for training.
# Epoch: 1
# Epoch 1 | Batch 1 / 8
# Epoch 1 | Batch 2 / 8
# Epoch 1 | Batch 3 / 8
# Epoch 1 | Batch 4 / 8
# Epoch 1 | Batch 5 / 8
# Epoch 1 | Batch 6 / 8
# Epoch 1 | Batch 7 / 8
# Epoch 1 | Batch 8 / 8
# Epoch 1 / 30:
# - Train MSE: 0.008182317
# - Val MSE: 0.008999289
# - Train Loss: 1.5149443e7
# - Val Loss: 518.49896
# - Train Entropy: 0.6938634
# - Val Entropy: 0.6931714
# Epoch: 2
# Epoch 2 | Batch 1 / 8
# Epoch 2 | Batch 2 / 8
# Epoch 2 | Batch 3 / 8
# Epoch 2 | Batch 4 / 8
# Epoch 2 | Batch 5 / 8
# Epoch 2 | Batch 6 / 8
# Epoch 2 | Batch 7 / 8
# Epoch 2 | Batch 8 / 8
# Epoch 2 / 30:
# - Train MSE: 0.008427602
# - Val MSE: 0.009382518
# - Train Loss: 598.5416
# - Val Loss: 50.786255
# - Train Entropy: 0.6937942
# - Val Entropy: 0.6939193
# Epoch: 3
# Epoch 3 | Batch 1 / 8
# Epoch 3 | Batch 2 / 8
# Epoch 3 | Batch 3 / 8
# Epoch 3 | Batch 4 / 8
# Epoch 3 | Batch 5 / 8
# Epoch 3 | Batch 6 / 8
# Epoch 3 | Batch 7 / 8
# Epoch 3 | Batch 8 / 8
# Epoch 3 / 30:
# - Train MSE: 0.008309871
# - Val MSE: 0.009452389
# - Train Loss: 10.614136
# - Val Loss: -162.3092
# - Train Entropy: 0.6940351
# - Val Entropy: 0.69458544
# Epoch: 4
# Epoch 4 | Batch 1 / 8
# Epoch 4 | Batch 2 / 8
# Epoch 4 | Batch 3 / 8
# Epoch 4 | Batch 4 / 8
# Epoch 4 | Batch 5 / 8
# Epoch 4 | Batch 6 / 8
# Epoch 4 | Batch 7 / 8
# Epoch 4 | Batch 8 / 8
# Epoch 4 / 30:
# - Train MSE: 0.0082384255
# - Val MSE: 0.0094259465
# - Train Loss: -676.40076
# - Val Loss: -437.20383
# - Train Entropy: 0.6942192
# - Val Entropy: 0.6949903
# Epoch: 5
# Epoch 5 | Batch 1 / 8
# Epoch 5 | Batch 2 / 8
# Epoch 5 | Batch 3 / 8
# Epoch 5 | Batch 4 / 8
# Epoch 5 | Batch 5 / 8
# Epoch 5 | Batch 6 / 8
# Epoch 5 | Batch 7 / 8
# Epoch 5 | Batch 8 / 8
# Epoch 5 / 30:
# - Train MSE: 0.008279836
# - Val MSE: 0.009469478
# - Train Loss: -1355.8767
# - Val Loss: -725.66907
# - Train Entropy: 0.69474506
# - Val Entropy: 0.6957029
# Epoch: 6
# Epoch 6 | Batch 1 / 8
# Epoch 6 | Batch 2 / 8
# Epoch 6 | Batch 3 / 8
# Epoch 6 | Batch 4 / 8
# Epoch 6 | Batch 5 / 8
# Epoch 6 | Batch 6 / 8
# Epoch 6 | Batch 7 / 8
# Epoch 6 | Batch 8 / 8
# Epoch 6 / 30:
# - Train MSE: 0.008129408
# - Val MSE: 0.00919774
# - Train Loss: -1070.6266
# - Val Loss: -906.8138
# - Train Entropy: 0.6942387
# - Val Entropy: 0.6951362
# Epoch: 7
# Epoch 7 | Batch 1 / 8
# Epoch 7 | Batch 2 / 8
# Epoch 7 | Batch 3 / 8
# Epoch 7 | Batch 4 / 8
# Epoch 7 | Batch 5 / 8
# Epoch 7 | Batch 6 / 8
# Epoch 7 | Batch 7 / 8
# Epoch 7 | Batch 8 / 8
# Epoch 7 / 30:
# - Train MSE: 0.008094614
# - Val MSE: 0.009197927
# - Train Loss: -1695.3129
# - Val Loss: -857.43317
# - Train Entropy: 0.69403684
# - Val Entropy: 0.6949834
# Epoch: 8
# Epoch 8 | Batch 1 / 8
# Epoch 8 | Batch 2 / 8
# Epoch 8 | Batch 3 / 8
# Epoch 8 | Batch 4 / 8
# Epoch 8 | Batch 5 / 8
# Epoch 8 | Batch 6 / 8
# Epoch 8 | Batch 7 / 8
# Epoch 8 | Batch 8 / 8
# Epoch 8 / 30:
# - Train MSE: 0.008221345
# - Val MSE: 0.009631429
# - Train Loss: -1939.3284
# - Val Loss: -758.7207
# - Train Entropy: 0.695019
# - Val Entropy: 0.69665796
# Epoch: 9
# Epoch 9 | Batch 1 / 8
# Epoch 9 | Batch 2 / 8
# Epoch 9 | Batch 3 / 8
# Epoch 9 | Batch 4 / 8
# Epoch 9 | Batch 5 / 8
# Epoch 9 | Batch 6 / 8
# Epoch 9 | Batch 7 / 8
# Epoch 9 | Batch 8 / 8
# Epoch 9 / 30:
# - Train MSE: 0.008120392
# - Val MSE: 0.009346402
# - Train Loss: -2081.8052
# - Val Loss: -878.1835
# - Train Entropy: 0.6946257
# - Val Entropy: 0.6961569
# Epoch: 10
# Epoch 10 | Batch 1 / 8
# Epoch 10 | Batch 2 / 8
# Epoch 10 | Batch 3 / 8
# Epoch 10 | Batch 4 / 8
# Epoch 10 | Batch 5 / 8
# Epoch 10 | Batch 6 / 8
# Epoch 10 | Batch 7 / 8
# Epoch 10 | Batch 8 / 8
# Epoch 10 / 30:
# - Train MSE: 0.008079128
# - Val MSE: 0.009335709
# - Train Loss: -2219.9321
# - Val Loss: -908.0653
# - Train Entropy: 0.69446915
# - Val Entropy: 0.696112
# Epoch: 11
# Epoch 11 | Batch 1 / 8
# Epoch 11 | Batch 2 / 8
# Epoch 11 | Batch 3 / 8
# Epoch 11 | Batch 4 / 8
# Epoch 11 | Batch 5 / 8
# Epoch 11 | Batch 6 / 8
# Epoch 11 | Batch 7 / 8
# Epoch 11 | Batch 8 / 8
# Epoch 11 / 30:
# - Train MSE: 0.008116635
# - Val MSE: 0.009563959
# - Train Loss: -2339.4673
# - Val Loss: -843.00116
# - Train Entropy: 0.69491833
# - Val Entropy: 0.69712114
# Epoch: 12
# Epoch 12 | Batch 1 / 8
# Epoch 12 | Batch 2 / 8
# Epoch 12 | Batch 3 / 8
# Epoch 12 | Batch 4 / 8
# Epoch 12 | Batch 5 / 8
# Epoch 12 | Batch 6 / 8
# Epoch 12 | Batch 7 / 8
# Epoch 12 | Batch 8 / 8
# Epoch 12 / 30:
# - Train MSE: 0.008082805
# - Val MSE: 0.009434767
# - Train Loss: -2439.4998
# - Val Loss: -879.9952
# - Train Entropy: 0.69466364
# - Val Entropy: 0.69683594
# Epoch: 13
# Epoch 13 | Batch 1 / 8
# Epoch 13 | Batch 2 / 8
# Epoch 13 | Batch 3 / 8
# Epoch 13 | Batch 4 / 8
# Epoch 13 | Batch 5 / 8
# Epoch 13 | Batch 6 / 8
# Epoch 13 | Batch 7 / 8
# Epoch 13 | Batch 8 / 8
# Epoch 13 / 30:
# - Train MSE: 0.008155883
# - Val MSE: 0.00952094
# - Train Loss: -2538.0366
# - Val Loss: -849.10596
# - Train Entropy: 0.6947896
# - Val Entropy: 0.6971612
# Epoch: 14
# Epoch 14 | Batch 1 / 8
# Epoch 14 | Batch 2 / 8
# Epoch 14 | Batch 3 / 8
# Epoch 14 | Batch 4 / 8
# Epoch 14 | Batch 5 / 8
# Epoch 14 | Batch 6 / 8
# Epoch 14 | Batch 7 / 8
# Epoch 14 | Batch 8 / 8
# Epoch 14 / 30:
# - Train MSE: 0.00803145
# - Val MSE: 0.009331323
# - Train Loss: -2580.9553
# - Val Loss: -944.128
# - Train Entropy: 0.6943619
# - Val Entropy: 0.69647616
# Epoch: 15
# Epoch 15 | Batch 1 / 8
# Epoch 15 | Batch 2 / 8
# Epoch 15 | Batch 3 / 8
# Epoch 15 | Batch 4 / 8
# Epoch 15 | Batch 5 / 8
# Epoch 15 | Batch 6 / 8
# Epoch 15 | Batch 7 / 8
# Epoch 15 | Batch 8 / 8
# Epoch 15 / 30:
# - Train MSE: 0.008141065
# - Val MSE: 0.009920962
# - Train Loss: -2586.8794
# - Val Loss: -679.8691
# - Train Entropy: 0.6952488
# - Val Entropy: 0.6985072
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# Epoch 16 | Batch 3 / 8
# Epoch 16 | Batch 4 / 8
# Epoch 16 | Batch 5 / 8
# Epoch 16 | Batch 6 / 8
# Epoch 16 | Batch 7 / 8
# Epoch 16 | Batch 8 / 8
# Epoch 16 / 30:
# - Train MSE: 0.0080344435
# - Val MSE: 0.009268956
# - Train Loss: -2666.4329
# - Val Loss: -986.0403
# - Train Entropy: 0.6942294
# - Val Entropy: 0.6962484
# Epoch: 17
# Epoch 17 | Batch 1 / 8
# Epoch 17 | Batch 2 / 8
# Epoch 17 | Batch 3 / 8
# Epoch 17 | Batch 4 / 8
# Epoch 17 | Batch 5 / 8
# Epoch 17 | Batch 6 / 8
# Epoch 17 | Batch 7 / 8
# Epoch 17 | Batch 8 / 8
# Epoch 17 / 30:
# - Train MSE: 0.0081668515
# - Val MSE: 0.009950971
# - Train Loss: -2755.2202
# - Val Loss: -685.8875
# - Train Entropy: 0.69534814
# - Val Entropy: 0.6986719
# Epoch: 18
# Epoch 18 | Batch 1 / 8
# Epoch 18 | Batch 2 / 8
# Epoch 18 | Batch 3 / 8
# Epoch 18 | Batch 4 / 8
# Epoch 18 | Batch 5 / 8
# Epoch 18 | Batch 6 / 8
# Epoch 18 | Batch 7 / 8
# Epoch 18 | Batch 8 / 8
# Epoch 18 / 30:
# - Train MSE: 0.008165055
# - Val MSE: 0.009311732
# - Train Loss: -2781.8677
# - Val Loss: -974.3396
# - Train Entropy: 0.6944201
# - Val Entropy: 0.6964789
# Epoch: 19
# Epoch 19 | Batch 1 / 8
# Epoch 19 | Batch 2 / 8
# Epoch 19 | Batch 3 / 8
# Epoch 19 | Batch 4 / 8
# Epoch 19 | Batch 5 / 8
# Epoch 19 | Batch 6 / 8
# Epoch 19 | Batch 7 / 8
# Epoch 19 | Batch 8 / 8
# Epoch 19 / 30:
# - Train MSE: 0.008076065
# - Val MSE: 0.009772225
# - Train Loss: -2854.785
# - Val Loss: -767.8196
# - Train Entropy: 0.6951171
# - Val Entropy: 0.69815356
# Epoch: 20
# Epoch 20 | Batch 1 / 8
# Epoch 20 | Batch 2 / 8
# Epoch 20 | Batch 3 / 8
# Epoch 20 | Batch 4 / 8
# Epoch 20 | Batch 5 / 8
# Epoch 20 | Batch 6 / 8
# Epoch 20 | Batch 7 / 8
# Epoch 20 | Batch 8 / 8
# Epoch 20 / 30:
# - Train MSE: 0.0080499
# - Val MSE: 0.009583312
# - Train Loss: -2920.848
# - Val Loss: -859.37756
# - Train Entropy: 0.6946052
# - Val Entropy: 0.6974754
# Epoch: 21
# Epoch 21 | Batch 1 / 8
# Epoch 21 | Batch 2 / 8
# Epoch 21 | Batch 3 / 8
# Epoch 21 | Batch 4 / 8
# Epoch 21 | Batch 5 / 8
# Epoch 21 | Batch 6 / 8
# Epoch 21 | Batch 7 / 8
# Epoch 21 | Batch 8 / 8
# Epoch 21 / 30:
# - Train MSE: 0.0080267275
# - Val MSE: 0.009658724
# - Train Loss: -2985.434
# - Val Loss: -802.6237
# - Train Entropy: 0.69484013
# - Val Entropy: 0.69786644
# Epoch: 22
# Epoch 22 | Batch 1 / 8
# Epoch 22 | Batch 2 / 8
# Epoch 22 | Batch 3 / 8
# Epoch 22 | Batch 4 / 8
# Epoch 22 | Batch 5 / 8
# Epoch 22 | Batch 6 / 8
# Epoch 22 | Batch 7 / 8
# Epoch 22 | Batch 8 / 8
# Epoch 22 / 30:
# - Train MSE: 0.007998575
# - Val MSE: 0.009707785
# - Train Loss: -3031.1406
# - Val Loss: -813.41046
# - Train Entropy: 0.69478655
# - Val Entropy: 0.6978833
# Epoch: 23
# Epoch 23 | Batch 1 / 8
# Epoch 23 | Batch 2 / 8
# Epoch 23 | Batch 3 / 8
# Epoch 23 | Batch 4 / 8
# Epoch 23 | Batch 5 / 8
# Epoch 23 | Batch 6 / 8
# Epoch 23 | Batch 7 / 8
# Epoch 23 | Batch 8 / 8
# Epoch 23 / 30:
# - Train MSE: 0.00801269
# - Val MSE: 0.00989206
# - Train Loss: -3094.2021
# - Val Loss: -730.3575
# - Train Entropy: 0.69492275
# - Val Entropy: 0.69853795
# Epoch: 24
# Epoch 24 | Batch 1 / 8
# Epoch 24 | Batch 2 / 8
# Epoch 24 | Batch 3 / 8
# Epoch 24 | Batch 4 / 8
# Epoch 24 | Batch 5 / 8
# Epoch 24 | Batch 6 / 8
# Epoch 24 | Batch 7 / 8
# Epoch 24 | Batch 8 / 8
# Epoch 24 / 30:
# - Train MSE: 0.007996417
# - Val MSE: 0.009874945
# - Train Loss: -3142.652
# - Val Loss: -721.7035
# - Train Entropy: 0.6948698
# - Val Entropy: 0.69854176
# Epoch: 25
# Epoch 25 | Batch 1 / 8
# Epoch 25 | Batch 2 / 8
# Epoch 25 | Batch 3 / 8
# Epoch 25 | Batch 4 / 8
# Epoch 25 | Batch 5 / 8
# Epoch 25 | Batch 6 / 8
# Epoch 25 | Batch 7 / 8
# Epoch 25 | Batch 8 / 8
# Epoch 25 / 30:
# - Train MSE: 0.008019911
# - Val MSE: 0.010018029
# - Train Loss: -3207.221
# - Val Loss: -683.29346
# - Train Entropy: 0.6949785
# - Val Entropy: 0.69889724
# Epoch: 26
# Epoch 26 | Batch 1 / 8
# Epoch 26 | Batch 2 / 8
# Epoch 26 | Batch 3 / 8
# Epoch 26 | Batch 4 / 8
# Epoch 26 | Batch 5 / 8
# Epoch 26 | Batch 6 / 8
# Epoch 26 | Batch 7 / 8
# Epoch 26 | Batch 8 / 8
# Epoch 26 / 30:
# - Train MSE: 0.008008702
# - Val MSE: 0.009977507
# - Train Loss: -3251.1328
# - Val Loss: -687.3721
# - Train Entropy: 0.69498664
# - Val Entropy: 0.6988315
# Epoch: 27
# Epoch 27 | Batch 1 / 8
# Epoch 27 | Batch 2 / 8
# Epoch 27 | Batch 3 / 8
# Epoch 27 | Batch 4 / 8
# Epoch 27 | Batch 5 / 8
# Epoch 27 | Batch 6 / 8
# Epoch 27 | Batch 7 / 8
# Epoch 27 | Batch 8 / 8
# Epoch 27 / 30:
# - Train MSE: 0.008061918
# - Val MSE: 0.010014897
# - Train Loss: -3279.9004
# - Val Loss: -700.5779
# - Train Entropy: 0.6948523
# - Val Entropy: 0.6988337
# Epoch: 28
# Epoch 28 | Batch 1 / 8
# Epoch 28 | Batch 2 / 8
# Epoch 28 | Batch 3 / 8
# Epoch 28 | Batch 4 / 8
# Epoch 28 | Batch 5 / 8
# Epoch 28 | Batch 6 / 8
# Epoch 28 | Batch 7 / 8
# Epoch 28 | Batch 8 / 8
# Epoch 28 / 30:
# - Train MSE: 0.008005733
# - Val MSE: 0.010138253
# - Train Loss: -3333.8115
# - Val Loss: -615.7457
# - Train Entropy: 0.69503975
# - Val Entropy: 0.699378
# Epoch: 29
# Epoch 29 | Batch 1 / 8
# Epoch 29 | Batch 2 / 8
# Epoch 29 | Batch 3 / 8
# Epoch 29 | Batch 4 / 8
# Epoch 29 | Batch 5 / 8
# Epoch 29 | Batch 6 / 8
# Epoch 29 | Batch 7 / 8
# Epoch 29 | Batch 8 / 8
# Epoch 29 / 30:
# - Train MSE: 0.007973253
# - Val MSE: 0.009903222
# - Train Loss: -3323.4368
# - Val Loss: -741.8124
# - Train Entropy: 0.6946677
# - Val Entropy: 0.69852555
# Epoch: 30
# Epoch 30 | Batch 1 / 8
# Epoch 30 | Batch 2 / 8
# Epoch 30 | Batch 3 / 8
# Epoch 30 | Batch 4 / 8
# Epoch 30 | Batch 5 / 8
# Epoch 30 | Batch 6 / 8
# Epoch 30 | Batch 7 / 8
# Epoch 30 | Batch 8 / 8
# Epoch 30 / 30:
# - Train MSE: 0.008117016
# - Val MSE: 0.011215225
# - Train Loss: -3343.623
# - Val Loss: -203.85135
# - Train Entropy: 0.6955453
# - Val Entropy: 0.70239884
#   Latent Dim: 10
# Using GPU for training.
# Epoch: 1
# Epoch 1 | Batch 1 / 8
# Epoch 1 | Batch 2 / 8
# Epoch 1 | Batch 3 / 8
# Epoch 1 | Batch 4 / 8
# Epoch 1 | Batch 5 / 8
# Epoch 1 | Batch 6 / 8
# Epoch 1 | Batch 7 / 8
# Epoch 1 | Batch 8 / 8
# Epoch 1 / 30:
# - Train MSE: 0.01752018
# - Val MSE: 0.031856716
# - Train Loss: 8.2567107e9
# - Val Loss: 10820.709
# - Train Entropy: 0.7223964
# - Val Entropy: 0.7581977
# Epoch: 2
# Epoch 2 | Batch 1 / 8
# Epoch 2 | Batch 2 / 8
# Epoch 2 | Batch 3 / 8
# Epoch 2 | Batch 4 / 8
# Epoch 2 | Batch 5 / 8
# Epoch 2 | Batch 6 / 8
# Epoch 2 | Batch 7 / 8
# Epoch 2 | Batch 8 / 8
# Epoch 2 / 30:
# - Train MSE: 0.008300331
# - Val MSE: 0.0090743145
# - Train Loss: 32916.527
# - Val Loss: 575.9954
# - Train Entropy: 0.6972881
# - Val Entropy: 0.69674045
# Epoch: 3
# Epoch 3 | Batch 1 / 8
# Epoch 3 | Batch 2 / 8
# Epoch 3 | Batch 3 / 8
# Epoch 3 | Batch 4 / 8
# Epoch 3 | Batch 5 / 8
# Epoch 3 | Batch 6 / 8
# Epoch 3 | Batch 7 / 8
# Epoch 3 | Batch 8 / 8
# Epoch 3 / 30:
# - Train MSE: 0.008147463
# - Val MSE: 0.009165047
# - Train Loss: 107209.016
# - Val Loss: -1137.3286
# - Train Entropy: 0.6937667
# - Val Entropy: 0.6943642
# Epoch: 4
# Epoch 4 | Batch 1 / 8
# Epoch 4 | Batch 2 / 8
# Epoch 4 | Batch 3 / 8
# Epoch 4 | Batch 4 / 8
# Epoch 4 | Batch 5 / 8
# Epoch 4 | Batch 6 / 8
# Epoch 4 | Batch 7 / 8
# Epoch 4 | Batch 8 / 8
# Epoch 4 / 30:
# - Train MSE: 0.008219579
# - Val MSE: 0.009417714
# - Train Loss: -1717.483
# - Val Loss: -1047.4386
# - Train Entropy: 0.69431883
# - Val Entropy: 0.69518536
# Epoch: 5
# Epoch 5 | Batch 1 / 8
# Epoch 5 | Batch 2 / 8
# Epoch 5 | Batch 3 / 8
# Epoch 5 | Batch 4 / 8
# Epoch 5 | Batch 5 / 8
# Epoch 5 | Batch 6 / 8
# Epoch 5 | Batch 7 / 8
# Epoch 5 | Batch 8 / 8
# Epoch 5 / 30:
# - Train MSE: 0.0082580745
# - Val MSE: 0.009544982
# - Train Loss: -2190.966
# - Val Loss: -981.12177
# - Train Entropy: 0.694876
# - Val Entropy: 0.6961212
# Epoch: 6
# Epoch 6 | Batch 1 / 8
# Epoch 6 | Batch 2 / 8
# Epoch 6 | Batch 3 / 8
# Epoch 6 | Batch 4 / 8
# Epoch 6 | Batch 5 / 8
# Epoch 6 | Batch 6 / 8
# Epoch 6 | Batch 7 / 8
# Epoch 6 | Batch 8 / 8
# Epoch 6 / 30:
# - Train MSE: 0.008359213
# - Val MSE: 0.009801946
# - Train Loss: -2394.1865
# - Val Loss: -926.93365
# - Train Entropy: 0.6955915
# - Val Entropy: 0.69738
# Epoch: 7
# Epoch 7 | Batch 1 / 8
# Epoch 7 | Batch 2 / 8
# Epoch 7 | Batch 3 / 8
# Epoch 7 | Batch 4 / 8
# Epoch 7 | Batch 5 / 8
# Epoch 7 | Batch 6 / 8
# Epoch 7 | Batch 7 / 8
# Epoch 7 | Batch 8 / 8
# Epoch 7 / 30:
# - Train MSE: 0.008085937
# - Val MSE: 0.00922864
# - Train Loss: -2491.0298
# - Val Loss: -1139.2427
# - Train Entropy: 0.6944371
# - Val Entropy: 0.6957592
# Epoch: 8
# Epoch 8 | Batch 1 / 8
# Epoch 8 | Batch 2 / 8
# Epoch 8 | Batch 3 / 8
# Epoch 8 | Batch 4 / 8
# Epoch 8 | Batch 5 / 8
# Epoch 8 | Batch 6 / 8
# Epoch 8 | Batch 7 / 8
# Epoch 8 | Batch 8 / 8
# Epoch 8 / 30:
# - Train MSE: 0.008135582
# - Val MSE: 0.009447725
# - Train Loss: -2542.7344
# - Val Loss: -1081.5309
# - Train Entropy: 0.69478333
# - Val Entropy: 0.69654065
# Epoch: 9
# Epoch 9 | Batch 1 / 8
# Epoch 9 | Batch 2 / 8
# Epoch 9 | Batch 3 / 8
# Epoch 9 | Batch 4 / 8
# Epoch 9 | Batch 5 / 8
# Epoch 9 | Batch 6 / 8
# Epoch 9 | Batch 7 / 8
# Epoch 9 | Batch 8 / 8
# Epoch 9 / 30:
# - Train MSE: 0.008190667
# - Val MSE: 0.00961926
# - Train Loss: -2613.8628
# - Val Loss: -986.20886
# - Train Entropy: 0.6953868
# - Val Entropy: 0.6975003
# Epoch: 10
# Epoch 10 | Batch 1 / 8
# Epoch 10 | Batch 2 / 8
# Epoch 10 | Batch 3 / 8
# Epoch 10 | Batch 4 / 8
# Epoch 10 | Batch 5 / 8
# Epoch 10 | Batch 6 / 8
# Epoch 10 | Batch 7 / 8
# Epoch 10 | Batch 8 / 8
# Epoch 10 / 30:
# - Train MSE: 0.008080981
# - Val MSE: 0.009279091
# - Train Loss: -2663.612
# - Val Loss: -1085.4622
# - Train Entropy: 0.6947486
# - Val Entropy: 0.6963246
# Epoch: 11
# Epoch 11 | Batch 1 / 8
# Epoch 11 | Batch 2 / 8
# Epoch 11 | Batch 3 / 8
# Epoch 11 | Batch 4 / 8
# Epoch 11 | Batch 5 / 8
# Epoch 11 | Batch 6 / 8
# Epoch 11 | Batch 7 / 8
# Epoch 11 | Batch 8 / 8
# Epoch 11 / 30:
# - Train MSE: 0.0080887405
# - Val MSE: 0.009383408
# - Train Loss: -2710.3618
# - Val Loss: -1051.5554
# - Train Entropy: 0.694978
# - Val Entropy: 0.6968692
# Epoch: 12
# Epoch 12 | Batch 1 / 8
# Epoch 12 | Batch 2 / 8
# Epoch 12 | Batch 3 / 8
# Epoch 12 | Batch 4 / 8
# Epoch 12 | Batch 5 / 8
# Epoch 12 | Batch 6 / 8
# Epoch 12 | Batch 7 / 8
# Epoch 12 | Batch 8 / 8
# Epoch 12 / 30:
# - Train MSE: 0.008081889
# - Val MSE: 0.009366184
# - Train Loss: -2747.7083
# - Val Loss: -1065.393
# - Train Entropy: 0.6949499
# - Val Entropy: 0.69687676
# Epoch: 13
# Epoch 13 | Batch 1 / 8
# Epoch 13 | Batch 2 / 8
# Epoch 13 | Batch 3 / 8
# Epoch 13 | Batch 4 / 8
# Epoch 13 | Batch 5 / 8
# Epoch 13 | Batch 6 / 8
# Epoch 13 | Batch 7 / 8
# Epoch 13 | Batch 8 / 8
# Epoch 13 / 30:
# - Train MSE: 0.008095681
# - Val MSE: 0.009448458
# - Train Loss: -2799.0159
# - Val Loss: -1063.9656
# - Train Entropy: 0.69519013
# - Val Entropy: 0.6973201
# Epoch: 14
# Epoch 14 | Batch 1 / 8
# Epoch 14 | Batch 2 / 8
# Epoch 14 | Batch 3 / 8
# Epoch 14 | Batch 4 / 8
# Epoch 14 | Batch 5 / 8
# Epoch 14 | Batch 6 / 8
# Epoch 14 | Batch 7 / 8
# Epoch 14 | Batch 8 / 8
# Epoch 14 / 30:
# - Train MSE: 0.0080373585
# - Val MSE: 0.009212738
# - Train Loss: -2829.6147
# - Val Loss: -1121.2272
# - Train Entropy: 0.6946982
# - Val Entropy: 0.69621307
# Epoch: 15
# Epoch 15 | Batch 1 / 8
# Epoch 15 | Batch 2 / 8
# Epoch 15 | Batch 3 / 8
# Epoch 15 | Batch 4 / 8
# Epoch 15 | Batch 5 / 8
# Epoch 15 | Batch 6 / 8
# Epoch 15 | Batch 7 / 8
# Epoch 15 | Batch 8 / 8
# Epoch 15 / 30:
# - Train MSE: 0.008137024
# - Val MSE: 0.009373732
# - Train Loss: -2864.4941
# - Val Loss: -1067.4681
# - Train Entropy: 0.6951597
# - Val Entropy: 0.69671816
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# Epoch 16 | Batch 3 / 8
# Epoch 16 | Batch 4 / 8
# Epoch 16 | Batch 5 / 8
# Epoch 16 | Batch 6 / 8
# Epoch 16 | Batch 7 / 8
# Epoch 16 | Batch 8 / 8
# Epoch 16 / 30:
# - Train MSE: 0.008024449
# - Val MSE: 0.009186302
# - Train Loss: -2901.4905
# - Val Loss: -1148.7588
# - Train Entropy: 0.69466573
# - Val Entropy: 0.69599444
# Epoch: 17
# Epoch 17 | Batch 1 / 8
# Epoch 17 | Batch 2 / 8
# Epoch 17 | Batch 3 / 8
# Epoch 17 | Batch 4 / 8
# Epoch 17 | Batch 5 / 8
# Epoch 17 | Batch 6 / 8
# Epoch 17 | Batch 7 / 8
# Epoch 17 | Batch 8 / 8
# Epoch 17 / 30:
# - Train MSE: 0.00812749
# - Val MSE: 0.009487036
# - Train Loss: -2954.8418
# - Val Loss: -1059.229
# - Train Entropy: 0.69539034
# - Val Entropy: 0.69727963
# Epoch: 18
# Epoch 18 | Batch 1 / 8
# Epoch 18 | Batch 2 / 8
# Epoch 18 | Batch 3 / 8
# Epoch 18 | Batch 4 / 8
# Epoch 18 | Batch 5 / 8
# Epoch 18 | Batch 6 / 8
# Epoch 18 | Batch 7 / 8
# Epoch 18 | Batch 8 / 8
# Epoch 18 / 30:
# - Train MSE: 0.008046545
# - Val MSE: 0.009154677
# - Train Loss: -3002.3574
# - Val Loss: -1125.7134
# - Train Entropy: 0.6948021
# - Val Entropy: 0.6958449
# Epoch: 19
# Epoch 19 | Batch 1 / 8
# Epoch 19 | Batch 2 / 8
# Epoch 19 | Batch 3 / 8
# Epoch 19 | Batch 4 / 8
# Epoch 19 | Batch 5 / 8
# Epoch 19 | Batch 6 / 8
# Epoch 19 | Batch 7 / 8
# Epoch 19 | Batch 8 / 8
# Epoch 19 / 30:
# - Train MSE: 0.008190536
# - Val MSE: 0.009369931
# - Train Loss: -3051.185
# - Val Loss: -1117.1825
# - Train Entropy: 0.6953794
# - Val Entropy: 0.69678605
# Epoch: 20
# Epoch 20 | Batch 1 / 8
# Epoch 20 | Batch 2 / 8
# Epoch 20 | Batch 3 / 8
# Epoch 20 | Batch 4 / 8
# Epoch 20 | Batch 5 / 8
# Epoch 20 | Batch 6 / 8
# Epoch 20 | Batch 7 / 8
# Epoch 20 | Batch 8 / 8
# Epoch 20 / 30:
# - Train MSE: 0.008069247
# - Val MSE: 0.009226207
# - Train Loss: -3097.379
# - Val Loss: -1151.5529
# - Train Entropy: 0.69494593
# - Val Entropy: 0.69619834
# Epoch: 21
# Epoch 21 | Batch 1 / 8
# Epoch 21 | Batch 2 / 8
# Epoch 21 | Batch 3 / 8
# Epoch 21 | Batch 4 / 8
# Epoch 21 | Batch 5 / 8
# Epoch 21 | Batch 6 / 8
# Epoch 21 | Batch 7 / 8
# Epoch 21 | Batch 8 / 8
# Epoch 21 / 30:
# - Train MSE: 0.008038072
# - Val MSE: 0.00919692
# - Train Loss: -3170.1243
# - Val Loss: -1173.2417
# - Train Entropy: 0.6948885
# - Val Entropy: 0.6959323
# Epoch: 22
# Epoch 22 | Batch 1 / 8
# Epoch 22 | Batch 2 / 8
# Epoch 22 | Batch 3 / 8
# Epoch 22 | Batch 4 / 8
# Epoch 22 | Batch 5 / 8
# Epoch 22 | Batch 6 / 8
# Epoch 22 | Batch 7 / 8
# Epoch 22 | Batch 8 / 8
# Epoch 22 / 30:
# - Train MSE: 0.008085237
# - Val MSE: 0.009287724
# - Train Loss: -3239.7727
# - Val Loss: -1122.3431
# - Train Entropy: 0.69537324
# - Val Entropy: 0.69653034
# Epoch: 23
# Epoch 23 | Batch 1 / 8
# Epoch 23 | Batch 2 / 8
# Epoch 23 | Batch 3 / 8
# Epoch 23 | Batch 4 / 8
# Epoch 23 | Batch 5 / 8
# Epoch 23 | Batch 6 / 8
# Epoch 23 | Batch 7 / 8
# Epoch 23 | Batch 8 / 8
# Epoch 23 / 30:
# - Train MSE: 0.007977068
# - Val MSE: 0.00926025
# - Train Loss: -3306.0398
# - Val Loss: -1164.4904
# - Train Entropy: 0.69473976
# - Val Entropy: 0.69623756
# Epoch: 24
# Epoch 24 | Batch 1 / 8
# Epoch 24 | Batch 2 / 8
# Epoch 24 | Batch 3 / 8
# Epoch 24 | Batch 4 / 8
# Epoch 24 | Batch 5 / 8
# Epoch 24 | Batch 6 / 8
# Epoch 24 | Batch 7 / 8
# Epoch 24 | Batch 8 / 8
# Epoch 24 / 30:
# - Train MSE: 0.008161434
# - Val MSE: 0.009378107
# - Train Loss: -3382.9956
# - Val Loss: -1090.7423
# - Train Entropy: 0.6955464
# - Val Entropy: 0.6969581
# Epoch: 25
# Epoch 25 | Batch 1 / 8
# Epoch 25 | Batch 2 / 8
# Epoch 25 | Batch 3 / 8
# Epoch 25 | Batch 4 / 8
# Epoch 25 | Batch 5 / 8
# Epoch 25 | Batch 6 / 8
# Epoch 25 | Batch 7 / 8
# Epoch 25 | Batch 8 / 8
# Epoch 25 / 30:
# - Train MSE: 0.007947882
# - Val MSE: 0.009141427
# - Train Loss: -3428.3735
# - Val Loss: -1209.7047
# - Train Entropy: 0.6944568
# - Val Entropy: 0.6956966
# Epoch: 26
# Epoch 26 | Batch 1 / 8
# Epoch 26 | Batch 2 / 8
# Epoch 26 | Batch 3 / 8
# Epoch 26 | Batch 4 / 8
# Epoch 26 | Batch 5 / 8
# Epoch 26 | Batch 6 / 8
# Epoch 26 | Batch 7 / 8
# Epoch 26 | Batch 8 / 8
# Epoch 26 / 30:
# - Train MSE: 0.008053094
# - Val MSE: 0.00932209
# - Train Loss: -3544.863
# - Val Loss: -1072.3893
# - Train Entropy: 0.69537675
# - Val Entropy: 0.6966267
# Epoch: 27
# Epoch 27 | Batch 1 / 8
# Epoch 27 | Batch 2 / 8
# Epoch 27 | Batch 3 / 8
# Epoch 27 | Batch 4 / 8
# Epoch 27 | Batch 5 / 8
# Epoch 27 | Batch 6 / 8
# Epoch 27 | Batch 7 / 8
# Epoch 27 | Batch 8 / 8
# Epoch 27 / 30:
# - Train MSE: 0.008009204
# - Val MSE: 0.009310936
# - Train Loss: -3625.384
# - Val Loss: -1128.8345
# - Train Entropy: 0.69504464
# - Val Entropy: 0.6965506
# Epoch: 28
# Epoch 28 | Batch 1 / 8
# Epoch 28 | Batch 2 / 8
# Epoch 28 | Batch 3 / 8
# Epoch 28 | Batch 4 / 8
# Epoch 28 | Batch 5 / 8
# Epoch 28 | Batch 6 / 8
# Epoch 28 | Batch 7 / 8
# Epoch 28 | Batch 8 / 8
# Epoch 28 / 30:
# - Train MSE: 0.007920559
# - Val MSE: 0.009273493
# - Train Loss: -3687.6943
# - Val Loss: -1196.5372
# - Train Entropy: 0.6946217
# - Val Entropy: 0.6963352
# Epoch: 29
# Epoch 29 | Batch 1 / 8
# Epoch 29 | Batch 2 / 8
# Epoch 29 | Batch 3 / 8
# Epoch 29 | Batch 4 / 8
# Epoch 29 | Batch 5 / 8
# Epoch 29 | Batch 6 / 8
# Epoch 29 | Batch 7 / 8
# Epoch 29 | Batch 8 / 8
# Epoch 29 / 30:
# - Train MSE: 0.008023551
# - Val MSE: 0.009462702
# - Train Loss: -3788.4626
# - Val Loss: -1075.769
# - Train Entropy: 0.6952682
# - Val Entropy: 0.6971285
# Epoch: 30
# Epoch 30 | Batch 1 / 8
# Epoch 30 | Batch 2 / 8
# Epoch 30 | Batch 3 / 8
# Epoch 30 | Batch 4 / 8
# Epoch 30 | Batch 5 / 8
# Epoch 30 | Batch 6 / 8
# Epoch 30 | Batch 7 / 8
# Epoch 30 | Batch 8 / 8
# Epoch 30 / 30:
# - Train MSE: 0.008127256
# - Val MSE: 0.009669887
# - Train Loss: -3848.2456
# - Val Loss: -935.4829
# - Train Entropy: 0.6955453
# - Val Entropy: 0.69790155
#   Latent Dim: 20
# Using GPU for training.
# Epoch: 1
# Epoch 1 | Batch 1 / 8
# Epoch 1 | Batch 2 / 8
# Epoch 1 | Batch 3 / 8
# Epoch 1 | Batch 4 / 8
# Epoch 1 | Batch 5 / 8
# Epoch 1 | Batch 6 / 8
# Epoch 1 | Batch 7 / 8
# Epoch 1 | Batch 8 / 8
# Epoch 1 / 30:
# - Train MSE: 0.008086477
# - Val MSE: 0.008998471
# - Train Loss: 3.295996e11
# - Val Loss: 2216.8154
# - Train Entropy: 0.69325125
# - Val Entropy: 0.69382685
# Epoch: 2
# Epoch 2 | Batch 1 / 8
# Epoch 2 | Batch 2 / 8
# Epoch 2 | Batch 3 / 8
# Epoch 2 | Batch 4 / 8
# Epoch 2 | Batch 5 / 8
# Epoch 2 | Batch 6 / 8
# Epoch 2 | Batch 7 / 8
# Epoch 2 | Batch 8 / 8
# Epoch 2 / 30:
# - Train MSE: 0.008109014
# - Val MSE: 0.009008237
# - Train Loss: 9.982358e6
# - Val Loss: -778.2355
# - Train Entropy: 0.6932951
# - Val Entropy: 0.6933736
# Epoch: 3
# Epoch 3 | Batch 1 / 8
# Epoch 3 | Batch 2 / 8
# Epoch 3 | Batch 3 / 8
# Epoch 3 | Batch 4 / 8
# Epoch 3 | Batch 5 / 8
# Epoch 3 | Batch 6 / 8
# Epoch 3 | Batch 7 / 8
# Epoch 3 | Batch 8 / 8
# Epoch 3 / 30:
# - Train MSE: 0.008377898
# - Val MSE: 0.009499486
# - Train Loss: 505431.2
# - Val Loss: -993.0675
# - Train Entropy: 0.694183
# - Val Entropy: 0.6950603
# Epoch: 4
# Epoch 4 | Batch 1 / 8
# Epoch 4 | Batch 2 / 8
# Epoch 4 | Batch 3 / 8
# Epoch 4 | Batch 4 / 8
# Epoch 4 | Batch 5 / 8
# Epoch 4 | Batch 6 / 8
# Epoch 4 | Batch 7 / 8
# Epoch 4 | Batch 8 / 8
# Epoch 4 / 30:
# - Train MSE: 0.008251958
# - Val MSE: 0.009505547
# - Train Loss: 30353.219
# - Val Loss: -1028.0977
# - Train Entropy: 0.69443506
# - Val Entropy: 0.6958893
# Epoch: 5
# Epoch 5 | Batch 1 / 8
# Epoch 5 | Batch 2 / 8
# Epoch 5 | Batch 3 / 8
# Epoch 5 | Batch 4 / 8
# Epoch 5 | Batch 5 / 8
# Epoch 5 | Batch 6 / 8
# Epoch 5 | Batch 7 / 8
# Epoch 5 | Batch 8 / 8
# Epoch 5 / 30:
# - Train MSE: 0.008296314
# - Val MSE: 0.009761271
# - Train Loss: 1164.4355
# - Val Loss: -1011.4077
# - Train Entropy: 0.6946932
# - Val Entropy: 0.69702196
# Epoch: 6
# Epoch 6 | Batch 1 / 8
# Epoch 6 | Batch 2 / 8
# Epoch 6 | Batch 3 / 8
# Epoch 6 | Batch 4 / 8
# Epoch 6 | Batch 5 / 8
# Epoch 6 | Batch 6 / 8
# Epoch 6 | Batch 7 / 8
# Epoch 6 | Batch 8 / 8
# Epoch 6 / 30:
# - Train MSE: 0.008222758
# - Val MSE: 0.00977735
# - Train Loss: -1651.144
# - Val Loss: -997.48785
# - Train Entropy: 0.6947646
# - Val Entropy: 0.6971118
# Epoch: 7
# Epoch 7 | Batch 1 / 8
# Epoch 7 | Batch 2 / 8
# Epoch 7 | Batch 3 / 8
# Epoch 7 | Batch 4 / 8
# Epoch 7 | Batch 5 / 8
# Epoch 7 | Batch 6 / 8
# Epoch 7 | Batch 7 / 8
# Epoch 7 | Batch 8 / 8
# Epoch 7 / 30:
# - Train MSE: 0.008189002
# - Val MSE: 0.009619992
# - Train Loss: -2057.4258
# - Val Loss: -1027.2151
# - Train Entropy: 0.6946701
# - Val Entropy: 0.6969545
# Epoch: 8
# Epoch 8 | Batch 1 / 8
# Epoch 8 | Batch 2 / 8
# Epoch 8 | Batch 3 / 8
# Epoch 8 | Batch 4 / 8
# Epoch 8 | Batch 5 / 8
# Epoch 8 | Batch 6 / 8
# Epoch 8 | Batch 7 / 8
# Epoch 8 | Batch 8 / 8
# Epoch 8 / 30:
# - Train MSE: 0.008258981
# - Val MSE: 0.009855157
# - Train Loss: -2203.3577
# - Val Loss: -940.4822
# - Train Entropy: 0.69504267
# - Val Entropy: 0.6977212
# Epoch: 9
# Epoch 9 | Batch 1 / 8
# Epoch 9 | Batch 2 / 8
# Epoch 9 | Batch 3 / 8
# Epoch 9 | Batch 4 / 8
# Epoch 9 | Batch 5 / 8
# Epoch 9 | Batch 6 / 8
# Epoch 9 | Batch 7 / 8
# Epoch 9 | Batch 8 / 8
# Epoch 9 / 30:
# - Train MSE: 0.008185002
# - Val MSE: 0.009632103
# - Train Loss: -2330.856
# - Val Loss: -983.01575
# - Train Entropy: 0.69484526
# - Val Entropy: 0.6970607
# Epoch: 10
# Epoch 10 | Batch 1 / 8
# Epoch 10 | Batch 2 / 8
# Epoch 10 | Batch 3 / 8
# Epoch 10 | Batch 4 / 8
# Epoch 10 | Batch 5 / 8
# Epoch 10 | Batch 6 / 8
# Epoch 10 | Batch 7 / 8
# Epoch 10 | Batch 8 / 8
# Epoch 10 / 30:
# - Train MSE: 0.008200923
# - Val MSE: 0.00980069
# - Train Loss: -2425.999
# - Val Loss: -936.8134
# - Train Entropy: 0.6951087
# - Val Entropy: 0.69778407
# Epoch: 11
# Epoch 11 | Batch 1 / 8
# Epoch 11 | Batch 2 / 8
# Epoch 11 | Batch 3 / 8
# Epoch 11 | Batch 4 / 8
# Epoch 11 | Batch 5 / 8
# Epoch 11 | Batch 6 / 8
# Epoch 11 | Batch 7 / 8
# Epoch 11 | Batch 8 / 8
# Epoch 11 / 30:
# - Train MSE: 0.008154807
# - Val MSE: 0.009768911
# - Train Loss: -2453.4912
# - Val Loss: -960.9741
# - Train Entropy: 0.6948848
# - Val Entropy: 0.6978058
# Epoch: 12
# Epoch 12 | Batch 1 / 8
# Epoch 12 | Batch 2 / 8
# Epoch 12 | Batch 3 / 8
# Epoch 12 | Batch 4 / 8
# Epoch 12 | Batch 5 / 8
# Epoch 12 | Batch 6 / 8
# Epoch 12 | Batch 7 / 8
# Epoch 12 | Batch 8 / 8
# Epoch 12 / 30:
# - Train MSE: 0.008171508
# - Val MSE: 0.009852982
# - Train Loss: -2512.472
# - Val Loss: -940.332
# - Train Entropy: 0.6951239
# - Val Entropy: 0.6980954
# Epoch: 13
# Epoch 13 | Batch 1 / 8
# Epoch 13 | Batch 2 / 8
# Epoch 13 | Batch 3 / 8
# Epoch 13 | Batch 4 / 8
# Epoch 13 | Batch 5 / 8
# Epoch 13 | Batch 6 / 8
# Epoch 13 | Batch 7 / 8
# Epoch 13 | Batch 8 / 8
# Epoch 13 / 30:
# - Train MSE: 0.008112251
# - Val MSE: 0.009593471
# - Train Loss: -2518.887
# - Val Loss: -1011.254
# - Train Entropy: 0.69487935
# - Val Entropy: 0.6973461
# Epoch: 14
# Epoch 14 | Batch 1 / 8
# Epoch 14 | Batch 2 / 8
# Epoch 14 | Batch 3 / 8
# Epoch 14 | Batch 4 / 8
# Epoch 14 | Batch 5 / 8
# Epoch 14 | Batch 6 / 8
# Epoch 14 | Batch 7 / 8
# Epoch 14 | Batch 8 / 8
# Epoch 14 / 30:
# - Train MSE: 0.008145475
# - Val MSE: 0.009672081
# - Train Loss: -2546.765
# - Val Loss: -1000.8986
# - Train Entropy: 0.69496715
# - Val Entropy: 0.69751334
# Epoch: 15
# Epoch 15 | Batch 1 / 8
# Epoch 15 | Batch 2 / 8
# Epoch 15 | Batch 3 / 8
# Epoch 15 | Batch 4 / 8
# Epoch 15 | Batch 5 / 8
# Epoch 15 | Batch 6 / 8
# Epoch 15 | Batch 7 / 8
# Epoch 15 | Batch 8 / 8
# Epoch 15 / 30:
# - Train MSE: 0.008140725
# - Val MSE: 0.009734938
# - Train Loss: -2586.669
# - Val Loss: -948.0114
# - Train Entropy: 0.6951021
# - Val Entropy: 0.69788015
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# Epoch 16 | Batch 3 / 8
# Epoch 16 | Batch 4 / 8
# Epoch 16 | Batch 5 / 8
# Epoch 16 | Batch 6 / 8
# Epoch 16 | Batch 7 / 8
# Epoch 16 | Batch 8 / 8
# Epoch 16 / 30:
# - Train MSE: 0.008080498
# - Val MSE: 0.009554037
# - Train Loss: -2623.2153
# - Val Loss: -993.62024
# - Train Entropy: 0.69485104
# - Val Entropy: 0.6974183
# Epoch: 17
# Epoch 17 | Batch 1 / 8
# Epoch 17 | Batch 2 / 8
# Epoch 17 | Batch 3 / 8
# Epoch 17 | Batch 4 / 8
# Epoch 17 | Batch 5 / 8
# Epoch 17 | Batch 6 / 8
# Epoch 17 | Batch 7 / 8
# Epoch 17 | Batch 8 / 8
# Epoch 17 / 30:
# - Train MSE: 0.008052429
# - Val MSE: 0.009375263
# - Train Loss: -2703.5203
# - Val Loss: -1075.6144
# - Train Entropy: 0.69460905
# - Val Entropy: 0.69662654
# Epoch: 18
# Epoch 18 | Batch 1 / 8
# Epoch 18 | Batch 2 / 8
# Epoch 18 | Batch 3 / 8
# Epoch 18 | Batch 4 / 8
# Epoch 18 | Batch 5 / 8
# Epoch 18 | Batch 6 / 8
# Epoch 18 | Batch 7 / 8
# Epoch 18 | Batch 8 / 8
# Epoch 18 / 30:
# - Train MSE: 0.008091202
# - Val MSE: 0.009771719
# - Train Loss: -2721.206
# - Val Loss: -950.75104
# - Train Entropy: 0.69523907
# - Val Entropy: 0.6981487
# Epoch: 19
# Epoch 19 | Batch 1 / 8
# Epoch 19 | Batch 2 / 8
# Epoch 19 | Batch 3 / 8
# Epoch 19 | Batch 4 / 8
# Epoch 19 | Batch 5 / 8
# Epoch 19 | Batch 6 / 8
# Epoch 19 | Batch 7 / 8
# Epoch 19 | Batch 8 / 8
# Epoch 19 / 30:
# - Train MSE: 0.008021984
# - Val MSE: 0.009396815
# - Train Loss: -2773.7322
# - Val Loss: -1094.0812
# - Train Entropy: 0.6946034
# - Val Entropy: 0.69701105
# Epoch: 20
# Epoch 20 | Batch 1 / 8
# Epoch 20 | Batch 2 / 8
# Epoch 20 | Batch 3 / 8
# Epoch 20 | Batch 4 / 8
# Epoch 20 | Batch 5 / 8
# Epoch 20 | Batch 6 / 8
# Epoch 20 | Batch 7 / 8
# Epoch 20 | Batch 8 / 8
# Epoch 20 / 30:
# - Train MSE: 0.0080745835
# - Val MSE: 0.0094637005
# - Train Loss: -2821.1697
# - Val Loss: -1073.8179
# - Train Entropy: 0.6949518
# - Val Entropy: 0.6970877
# Epoch: 21
# Epoch 21 | Batch 1 / 8
# Epoch 21 | Batch 2 / 8
# Epoch 21 | Batch 3 / 8
# Epoch 21 | Batch 4 / 8
# Epoch 21 | Batch 5 / 8
# Epoch 21 | Batch 6 / 8
# Epoch 21 | Batch 7 / 8
# Epoch 21 | Batch 8 / 8
# Epoch 21 / 30:
# - Train MSE: 0.008018419
# - Val MSE: 0.009485234
# - Train Loss: -2901.6323
# - Val Loss: -1026.451
# - Train Entropy: 0.69494295
# - Val Entropy: 0.6973194
# Epoch: 22
# Epoch 22 | Batch 1 / 8
# Epoch 22 | Batch 2 / 8
# Epoch 22 | Batch 3 / 8
# Epoch 22 | Batch 4 / 8
# Epoch 22 | Batch 5 / 8
# Epoch 22 | Batch 6 / 8
# Epoch 22 | Batch 7 / 8
# Epoch 22 | Batch 8 / 8
# Epoch 22 / 30:
# - Train MSE: 0.00800289
# - Val MSE: 0.009270048
# - Train Loss: -2977.6152
# - Val Loss: -1128.3823
# - Train Entropy: 0.69464004
# - Val Entropy: 0.69640565
# Epoch: 23
# Epoch 23 | Batch 1 / 8
# Epoch 23 | Batch 2 / 8
# Epoch 23 | Batch 3 / 8
# Epoch 23 | Batch 4 / 8
# Epoch 23 | Batch 5 / 8
# Epoch 23 | Batch 6 / 8
# Epoch 23 | Batch 7 / 8
# Epoch 23 | Batch 8 / 8
# Epoch 23 / 30:
# - Train MSE: 0.008074646
# - Val MSE: 0.009480136
# - Train Loss: -3081.5125
# - Val Loss: -1069.6028
# - Train Entropy: 0.6951622
# - Val Entropy: 0.6972428
# Epoch: 24
# Epoch 24 | Batch 1 / 8
# Epoch 24 | Batch 2 / 8
# Epoch 24 | Batch 3 / 8
# Epoch 24 | Batch 4 / 8
# Epoch 24 | Batch 5 / 8
# Epoch 24 | Batch 6 / 8
# Epoch 24 | Batch 7 / 8
# Epoch 24 | Batch 8 / 8
# Epoch 24 / 30:
# - Train MSE: 0.007986824
# - Val MSE: 0.009244173
# - Train Loss: -3119.5222
# - Val Loss: -1123.6549
# - Train Entropy: 0.69487303
# - Val Entropy: 0.6963197
# Epoch: 25
# Epoch 25 | Batch 1 / 8
# Epoch 25 | Batch 2 / 8
# Epoch 25 | Batch 3 / 8
# Epoch 25 | Batch 4 / 8
# Epoch 25 | Batch 5 / 8
# Epoch 25 | Batch 6 / 8
# Epoch 25 | Batch 7 / 8
# Epoch 25 | Batch 8 / 8
# Epoch 25 / 30:
# - Train MSE: 0.007960735
# - Val MSE: 0.009245767
# - Train Loss: -3216.1296
# - Val Loss: -1186.297
# - Train Entropy: 0.69474006
# - Val Entropy: 0.6962512
# Epoch: 26
# Epoch 26 | Batch 1 / 8
# Epoch 26 | Batch 2 / 8
# Epoch 26 | Batch 3 / 8
# Epoch 26 | Batch 4 / 8
# Epoch 26 | Batch 5 / 8
# Epoch 26 | Batch 6 / 8
# Epoch 26 | Batch 7 / 8
# Epoch 26 | Batch 8 / 8
# Epoch 26 / 30:
# - Train MSE: 0.007981519
# - Val MSE: 0.009177089
# - Train Loss: -3333.2576
# - Val Loss: -1179.209
# - Train Entropy: 0.6947111
# - Val Entropy: 0.6958901
# Epoch: 27
# Epoch 27 | Batch 1 / 8
# Epoch 27 | Batch 2 / 8
# Epoch 27 | Batch 3 / 8
# Epoch 27 | Batch 4 / 8
# Epoch 27 | Batch 5 / 8
# Epoch 27 | Batch 6 / 8
# Epoch 27 | Batch 7 / 8
# Epoch 27 | Batch 8 / 8
# Epoch 27 / 30:
# - Train MSE: 0.008007068
# - Val MSE: 0.009297339
# - Train Loss: -3380.8801
# - Val Loss: -1160.0752
# - Train Entropy: 0.6948633
# - Val Entropy: 0.696292
# Epoch: 28
# Epoch 28 | Batch 1 / 8
# Epoch 28 | Batch 2 / 8
# Epoch 28 | Batch 3 / 8
# Epoch 28 | Batch 4 / 8
# Epoch 28 | Batch 5 / 8
# Epoch 28 | Batch 6 / 8
# Epoch 28 | Batch 7 / 8
# Epoch 28 | Batch 8 / 8
# Epoch 28 / 30:
# - Train MSE: 0.007962516
# - Val MSE: 0.009288736
# - Train Loss: -3507.2554
# - Val Loss: -1201.3973
# - Train Entropy: 0.69483125
# - Val Entropy: 0.69642806
# Epoch: 29
# Epoch 29 | Batch 1 / 8
# Epoch 29 | Batch 2 / 8
# Epoch 29 | Batch 3 / 8
# Epoch 29 | Batch 4 / 8
# Epoch 29 | Batch 5 / 8
# Epoch 29 | Batch 6 / 8
# Epoch 29 | Batch 7 / 8
# Epoch 29 | Batch 8 / 8
# Epoch 29 / 30:
# - Train MSE: 0.008010157
# - Val MSE: 0.009219765
# - Train Loss: -3641.9873
# - Val Loss: -1191.6647
# - Train Entropy: 0.695046
# - Val Entropy: 0.69616324
# Epoch: 30
# Epoch 30 | Batch 1 / 8
# Epoch 30 | Batch 2 / 8
# Epoch 30 | Batch 3 / 8
# Epoch 30 | Batch 4 / 8
# Epoch 30 | Batch 5 / 8
# Epoch 30 | Batch 6 / 8
# Epoch 30 | Batch 7 / 8
# Epoch 30 | Batch 8 / 8
# Epoch 30 / 30:
# - Train MSE: 0.008010559
# - Val MSE: 0.009216014
# - Train Loss: -3666.1323
# - Val Loss: -1189.2003
# - Train Entropy: 0.6949331
# - Val Entropy: 0.69604754
#   Latent Dim: 50
# Using GPU for training.
# Epoch: 1
# Epoch 1 | Batch 1 / 8
# Epoch 1 | Batch 2 / 8
# Epoch 1 | Batch 3 / 8
# Epoch 1 | Batch 4 / 8
# Epoch 1 | Batch 5 / 8
# Epoch 1 | Batch 6 / 8
# Epoch 1 | Batch 7 / 8
# Epoch 1 | Batch 8 / 8
# Epoch 1 / 30:
# - Train MSE: 0.008804106
# - Val MSE: 0.009020448
# - Train Loss: 3.8816476e9
# - Val Loss: 1692.9694
# - Train Entropy: 0.6982223
# - Val Entropy: 0.6950485
# Epoch: 2
# Epoch 2 | Batch 1 / 8
# Epoch 2 | Batch 2 / 8
# Epoch 2 | Batch 3 / 8
# Epoch 2 | Batch 4 / 8
# Epoch 2 | Batch 5 / 8
# Epoch 2 | Batch 6 / 8
# Epoch 2 | Batch 7 / 8
# Epoch 2 | Batch 8 / 8
# Epoch 2 / 30:
# - Train MSE: 0.008131097
# - Val MSE: 0.009087431
# - Train Loss: 107053.15
# - Val Loss: -519.0381
# - Train Entropy: 0.6946098
# - Val Entropy: 0.6949245
# Epoch: 3
# Epoch 3 | Batch 1 / 8
# Epoch 3 | Batch 2 / 8
# Epoch 3 | Batch 3 / 8
# Epoch 3 | Batch 4 / 8
# Epoch 3 | Batch 5 / 8
# Epoch 3 | Batch 6 / 8
# Epoch 3 | Batch 7 / 8
# Epoch 3 | Batch 8 / 8
# Epoch 3 / 30:
# - Train MSE: 0.008212357
# - Val MSE: 0.009195939
# - Train Loss: 132946.44
# - Val Loss: -1058.3622
# - Train Entropy: 0.6940441
# - Val Entropy: 0.6944137
# Epoch: 4
# Epoch 4 | Batch 1 / 8
# Epoch 4 | Batch 2 / 8
# Epoch 4 | Batch 3 / 8
# Epoch 4 | Batch 4 / 8
# Epoch 4 | Batch 5 / 8
# Epoch 4 | Batch 6 / 8
# Epoch 4 | Batch 7 / 8
# Epoch 4 | Batch 8 / 8
# Epoch 4 / 30:
# - Train MSE: 0.008387024
# - Val MSE: 0.0097805895
# - Train Loss: 2070.0176
# - Val Loss: -940.3782
# - Train Entropy: 0.69470143
# - Val Entropy: 0.69619787
# Epoch: 5
# Epoch 5 | Batch 1 / 8
# Epoch 5 | Batch 2 / 8
# Epoch 5 | Batch 3 / 8
# Epoch 5 | Batch 4 / 8
# Epoch 5 | Batch 5 / 8
# Epoch 5 | Batch 6 / 8
# Epoch 5 | Batch 7 / 8
# Epoch 5 | Batch 8 / 8
# Epoch 5 / 30:
# - Train MSE: 0.008242709
# - Val MSE: 0.009639349
# - Train Loss: -1650.8296
# - Val Loss: -957.6255
# - Train Entropy: 0.6947169
# - Val Entropy: 0.6965467
# Epoch: 6
# Epoch 6 | Batch 1 / 8
# Epoch 6 | Batch 2 / 8
# Epoch 6 | Batch 3 / 8
# Epoch 6 | Batch 4 / 8
# Epoch 6 | Batch 5 / 8
# Epoch 6 | Batch 6 / 8
# Epoch 6 | Batch 7 / 8
# Epoch 6 | Batch 8 / 8
# Epoch 6 / 30:
# - Train MSE: 0.008296566
# - Val MSE: 0.009796627
# - Train Loss: -2123.9534
# - Val Loss: -929.5794
# - Train Entropy: 0.69522214
# - Val Entropy: 0.697393
# Epoch: 7
# Epoch 7 | Batch 1 / 8
# Epoch 7 | Batch 2 / 8
# Epoch 7 | Batch 3 / 8
# Epoch 7 | Batch 4 / 8
# Epoch 7 | Batch 5 / 8
# Epoch 7 | Batch 6 / 8
# Epoch 7 | Batch 7 / 8
# Epoch 7 | Batch 8 / 8
# Epoch 7 / 30:
# - Train MSE: 0.008238568
# - Val MSE: 0.00968213
# - Train Loss: -2266.5007
# - Val Loss: -994.95636
# - Train Entropy: 0.6950138
# - Val Entropy: 0.6971966
# Epoch: 8
# Epoch 8 | Batch 1 / 8
# Epoch 8 | Batch 2 / 8
# Epoch 8 | Batch 3 / 8
# Epoch 8 | Batch 4 / 8
# Epoch 8 | Batch 5 / 8
# Epoch 8 | Batch 6 / 8
# Epoch 8 | Batch 7 / 8
# Epoch 8 | Batch 8 / 8
# Epoch 8 / 30:
# - Train MSE: 0.008159749
# - Val MSE: 0.009346466
# - Train Loss: -2374.922
# - Val Loss: -984.64355
# - Train Entropy: 0.69476336
# - Val Entropy: 0.6962335
# Epoch: 9
# Epoch 9 | Batch 1 / 8
# Epoch 9 | Batch 2 / 8
# Epoch 9 | Batch 3 / 8
# Epoch 9 | Batch 4 / 8
# Epoch 9 | Batch 5 / 8
# Epoch 9 | Batch 6 / 8
# Epoch 9 | Batch 7 / 8
# Epoch 9 | Batch 8 / 8
# Epoch 9 / 30:
# - Train MSE: 0.008282615
# - Val MSE: 0.009703662
# - Train Loss: -2431.0894
# - Val Loss: -836.863
# - Train Entropy: 0.6954165
# - Val Entropy: 0.697559
# Epoch: 10
# Epoch 10 | Batch 1 / 8
# Epoch 10 | Batch 2 / 8
# Epoch 10 | Batch 3 / 8
# Epoch 10 | Batch 4 / 8
# Epoch 10 | Batch 5 / 8
# Epoch 10 | Batch 6 / 8
# Epoch 10 | Batch 7 / 8
# Epoch 10 | Batch 8 / 8
# Epoch 10 / 30:
# - Train MSE: 0.008113326
# - Val MSE: 0.00961498
# - Train Loss: -2498.1455
# - Val Loss: -959.3731
# - Train Entropy: 0.69480836
# - Val Entropy: 0.6974642
# Epoch: 11
# Epoch 11 | Batch 1 / 8
# Epoch 11 | Batch 2 / 8
# Epoch 11 | Batch 3 / 8
# Epoch 11 | Batch 4 / 8
# Epoch 11 | Batch 5 / 8
# Epoch 11 | Batch 6 / 8
# Epoch 11 | Batch 7 / 8
# Epoch 11 | Batch 8 / 8
# Epoch 11 / 30:
# - Train MSE: 0.008149722
# - Val MSE: 0.009804504
# - Train Loss: -2562.6306
# - Val Loss: -734.6566
# - Train Entropy: 0.69517225
# - Val Entropy: 0.69818956
# Epoch: 12
# Epoch 12 | Batch 1 / 8
# Epoch 12 | Batch 2 / 8
# Epoch 12 | Batch 3 / 8
# Epoch 12 | Batch 4 / 8
# Epoch 12 | Batch 5 / 8
# Epoch 12 | Batch 6 / 8
# Epoch 12 | Batch 7 / 8
# Epoch 12 | Batch 8 / 8
# Epoch 12 / 30:
# - Train MSE: 0.008098843
# - Val MSE: 0.0095370095
# - Train Loss: -2609.2288
# - Val Loss: -1016.362
# - Train Entropy: 0.6948654
# - Val Entropy: 0.69719595
# Epoch: 13
# Epoch 13 | Batch 1 / 8
# Epoch 13 | Batch 2 / 8
# Epoch 13 | Batch 3 / 8
# Epoch 13 | Batch 4 / 8
# Epoch 13 | Batch 5 / 8
# Epoch 13 | Batch 6 / 8
# Epoch 13 | Batch 7 / 8
# Epoch 13 | Batch 8 / 8
# Epoch 13 / 30:
# - Train MSE: 0.008122521
# - Val MSE: 0.009639567
# - Train Loss: -2654.7197
# - Val Loss: -888.5263
# - Train Entropy: 0.69523287
# - Val Entropy: 0.69761056
# Epoch: 14
# Epoch 14 | Batch 1 / 8
# Epoch 14 | Batch 2 / 8
# Epoch 14 | Batch 3 / 8
# Epoch 14 | Batch 4 / 8
# Epoch 14 | Batch 5 / 8
# Epoch 14 | Batch 6 / 8
# Epoch 14 | Batch 7 / 8
# Epoch 14 | Batch 8 / 8
# Epoch 14 / 30:
# - Train MSE: 0.008036091
# - Val MSE: 0.009315978
# - Train Loss: -2697.3762
# - Val Loss: -1074.9436
# - Train Entropy: 0.6945147
# - Val Entropy: 0.69653666
# Epoch: 15
# Epoch 15 | Batch 1 / 8
# Epoch 15 | Batch 2 / 8
# Epoch 15 | Batch 3 / 8
# Epoch 15 | Batch 4 / 8
# Epoch 15 | Batch 5 / 8
# Epoch 15 | Batch 6 / 8
# Epoch 15 | Batch 7 / 8
# Epoch 15 | Batch 8 / 8
# Epoch 15 / 30:
# - Train MSE: 0.008100827
# - Val MSE: 0.009765636
# - Train Loss: -2722.58
# - Val Loss: -880.41266
# - Train Entropy: 0.6952299
# - Val Entropy: 0.6982922
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# Epoch 16 | Batch 3 / 8
# Epoch 16 | Batch 4 / 8
# Epoch 16 | Batch 5 / 8
# Epoch 16 | Batch 6 / 8
# Epoch 16 | Batch 7 / 8
# Epoch 16 | Batch 8 / 8
# Epoch 16 / 30:
# - Train MSE: 0.008014855
# - Val MSE: 0.0092260325
# - Train Loss: -2766.2227
# - Val Loss: -1059.0018
# - Train Entropy: 0.6945453
# - Val Entropy: 0.6961016
# Epoch: 17
# Epoch 17 | Batch 1 / 8
# Epoch 17 | Batch 2 / 8
# Epoch 17 | Batch 3 / 8
# Epoch 17 | Batch 4 / 8
# Epoch 17 | Batch 5 / 8
# Epoch 17 | Batch 6 / 8
# Epoch 17 | Batch 7 / 8
# Epoch 17 | Batch 8 / 8
# Epoch 17 / 30:
# - Train MSE: 0.008059214
# - Val MSE: 0.009624077
# - Train Loss: -2855.8174
# - Val Loss: -915.00366
# - Train Entropy: 0.6953639
# - Val Entropy: 0.69762987
# Epoch: 18
# Epoch 18 | Batch 1 / 8
# Epoch 18 | Batch 2 / 8
# Epoch 18 | Batch 3 / 8
# Epoch 18 | Batch 4 / 8
# Epoch 18 | Batch 5 / 8
# Epoch 18 | Batch 6 / 8
# Epoch 18 | Batch 7 / 8
# Epoch 18 | Batch 8 / 8
# Epoch 18 / 30:
# - Train MSE: 0.007970973
# - Val MSE: 0.009406361
# - Train Loss: -2873.871
# - Val Loss: -986.8464
# - Train Entropy: 0.69473034
# - Val Entropy: 0.6970818
# Epoch: 19
# Epoch 19 | Batch 1 / 8
# Epoch 19 | Batch 2 / 8
# Epoch 19 | Batch 3 / 8
# Epoch 19 | Batch 4 / 8
# Epoch 19 | Batch 5 / 8
# Epoch 19 | Batch 6 / 8
# Epoch 19 | Batch 7 / 8
# Epoch 19 | Batch 8 / 8
# Epoch 19 / 30:
# - Train MSE: 0.00795813
# - Val MSE: 0.009359904
# - Train Loss: -2974.656
# - Val Loss: -1049.935
# - Train Entropy: 0.694803
# - Val Entropy: 0.6969114
# Epoch: 20
# Epoch 20 | Batch 1 / 8
# Epoch 20 | Batch 2 / 8
# Epoch 20 | Batch 3 / 8
# Epoch 20 | Batch 4 / 8
# Epoch 20 | Batch 5 / 8
# Epoch 20 | Batch 6 / 8
# Epoch 20 | Batch 7 / 8
# Epoch 20 | Batch 8 / 8
# Epoch 20 / 30:
# - Train MSE: 0.007976117
# - Val MSE: 0.009378985
# - Train Loss: -3067.111
# - Val Loss: -960.78125
# - Train Entropy: 0.6950107
# - Val Entropy: 0.6967583
# Epoch: 21
# Epoch 21 | Batch 1 / 8
# Epoch 21 | Batch 2 / 8
# Epoch 21 | Batch 3 / 8
# Epoch 21 | Batch 4 / 8
# Epoch 21 | Batch 5 / 8
# Epoch 21 | Batch 6 / 8
# Epoch 21 | Batch 7 / 8
# Epoch 21 | Batch 8 / 8
# Epoch 21 / 30:
# - Train MSE: 0.007935901
# - Val MSE: 0.009124187
# - Train Loss: -3141.4978
# - Val Loss: -1134.7037
# - Train Entropy: 0.6943554
# - Val Entropy: 0.6955264
# Epoch: 22
# Epoch 22 | Batch 1 / 8
# Epoch 22 | Batch 2 / 8
# Epoch 22 | Batch 3 / 8
# Epoch 22 | Batch 4 / 8
# Epoch 22 | Batch 5 / 8
# Epoch 22 | Batch 6 / 8
# Epoch 22 | Batch 7 / 8
# Epoch 22 | Batch 8 / 8
# Epoch 22 / 30:
# - Train MSE: 0.008006356
# - Val MSE: 0.0093511315
# - Train Loss: -3235.0352
# - Val Loss: -942.7234
# - Train Entropy: 0.6952431
# - Val Entropy: 0.6967198
# Epoch: 23
# Epoch 23 | Batch 1 / 8
# Epoch 23 | Batch 2 / 8
# Epoch 23 | Batch 3 / 8
# Epoch 23 | Batch 4 / 8
# Epoch 23 | Batch 5 / 8
# Epoch 23 | Batch 6 / 8
# Epoch 23 | Batch 7 / 8
# Epoch 23 | Batch 8 / 8
# Epoch 23 / 30:
# - Train MSE: 0.007926195
# - Val MSE: 0.009218465
# - Train Loss: -3341.4429
# - Val Loss: -1059.2599
# - Train Entropy: 0.6947661
# - Val Entropy: 0.6962069
# Epoch: 24
# Epoch 24 | Batch 1 / 8
# Epoch 24 | Batch 2 / 8
# Epoch 24 | Batch 3 / 8
# Epoch 24 | Batch 4 / 8
# Epoch 24 | Batch 5 / 8
# Epoch 24 | Batch 6 / 8
# Epoch 24 | Batch 7 / 8
# Epoch 24 | Batch 8 / 8
# Epoch 24 / 30:
# - Train MSE: 0.007920449
# - Val MSE: 0.009225845
# - Train Loss: -3461.6453
# - Val Loss: -1105.599
# - Train Entropy: 0.6945669
# - Val Entropy: 0.6960158
# Epoch: 25
# Epoch 25 | Batch 1 / 8
# Epoch 25 | Batch 2 / 8
# Epoch 25 | Batch 3 / 8
# Epoch 25 | Batch 4 / 8
# Epoch 25 | Batch 5 / 8
# Epoch 25 | Batch 6 / 8
# Epoch 25 | Batch 7 / 8
# Epoch 25 | Batch 8 / 8
# Epoch 25 / 30:
# - Train MSE: 0.007881913
# - Val MSE: 0.0090663005
# - Train Loss: -3583.735
# - Val Loss: -1092.5131
# - Train Entropy: 0.69454205
# - Val Entropy: 0.69526064
# Epoch: 26
# Epoch 26 | Batch 1 / 8
# Epoch 26 | Batch 2 / 8
# Epoch 26 | Batch 3 / 8
# Epoch 26 | Batch 4 / 8
# Epoch 26 | Batch 5 / 8
# Epoch 26 | Batch 6 / 8
# Epoch 26 | Batch 7 / 8
# Epoch 26 | Batch 8 / 8
# Epoch 26 / 30:
# - Train MSE: 0.007923976
# - Val MSE: 0.009150321
# - Train Loss: -3659.6587
# - Val Loss: -1124.532
# - Train Entropy: 0.69480187
# - Val Entropy: 0.6956594
# Epoch: 27
# Epoch 27 | Batch 1 / 8
# Epoch 27 | Batch 2 / 8
# Epoch 27 | Batch 3 / 8
# Epoch 27 | Batch 4 / 8
# Epoch 27 | Batch 5 / 8
# Epoch 27 | Batch 6 / 8
# Epoch 27 | Batch 7 / 8
# Epoch 27 | Batch 8 / 8
# Epoch 27 / 30:
# - Train MSE: 0.008182067
# - Val MSE: 0.009211016
# - Train Loss: -3713.2156
# - Val Loss: -1091.0514
# - Train Entropy: 0.69559014
# - Val Entropy: 0.69604975
# Epoch: 28
# Epoch 28 | Batch 1 / 8
# Epoch 28 | Batch 2 / 8
# Epoch 28 | Batch 3 / 8
# Epoch 28 | Batch 4 / 8
# Epoch 28 | Batch 5 / 8
# Epoch 28 | Batch 6 / 8
# Epoch 28 | Batch 7 / 8
# Epoch 28 | Batch 8 / 8
# Epoch 28 / 30:
# - Train MSE: 0.007889176
# - Val MSE: 0.009068044
# - Train Loss: -3857.928
# - Val Loss: -1136.0431
# - Train Entropy: 0.6943506
# - Val Entropy: 0.6950533
# Epoch: 29
# Epoch 29 | Batch 1 / 8
# Epoch 29 | Batch 2 / 8
# Epoch 29 | Batch 3 / 8
# Epoch 29 | Batch 4 / 8
# Epoch 29 | Batch 5 / 8
# Epoch 29 | Batch 6 / 8
# Epoch 29 | Batch 7 / 8
# Epoch 29 | Batch 8 / 8
# Epoch 29 / 30:
# - Train MSE: 0.008045616
# - Val MSE: 0.009307244
# - Train Loss: -3959.9993
# - Val Loss: -1087.6178
# - Train Entropy: 0.6954297
# - Val Entropy: 0.69651324
# Epoch: 30
# Epoch 30 | Batch 1 / 8
# Epoch 30 | Batch 2 / 8
# Epoch 30 | Batch 3 / 8
# Epoch 30 | Batch 4 / 8
# Epoch 30 | Batch 5 / 8
# Epoch 30 | Batch 6 / 8
# Epoch 30 | Batch 7 / 8
# Epoch 30 | Batch 8 / 8
# Epoch 30 / 30:
# - Train MSE: 0.008144396
# - Val MSE: 0.009202338
# - Train Loss: -4084.6824
# - Val Loss: -1050.0532
# - Train Entropy: 0.6956468
# - Val Entropy: 0.69589955
#   Latent Dim: 100
# Using GPU for training.
# Epoch: 1
# Epoch 1 | Batch 1 / 8
# Epoch 1 | Batch 2 / 8
# Epoch 1 | Batch 3 / 8
# Epoch 1 | Batch 4 / 8
# Epoch 1 | Batch 5 / 8
# Epoch 1 | Batch 6 / 8
# Epoch 1 | Batch 7 / 8
# Epoch 1 | Batch 8 / 8
# Epoch 1 / 30:
# - Train MSE: 0.008087992
# - Val MSE: 0.008998244
# - Train Loss: 2.208083e11
# - Val Loss: 3470.4873
# - Train Entropy: 0.6934811
# - Val Entropy: 0.69328517
# Epoch: 2
# Epoch 2 | Batch 1 / 8
# Epoch 2 | Batch 2 / 8
# Epoch 2 | Batch 3 / 8
# Epoch 2 | Batch 4 / 8
# Epoch 2 | Batch 5 / 8
# Epoch 2 | Batch 6 / 8
# Epoch 2 | Batch 7 / 8
# Epoch 2 | Batch 8 / 8
# Epoch 2 / 30:
# - Train MSE: 0.00807786
# - Val MSE: 0.00899364
# - Train Loss: 6.852256e7
# - Val Loss: -513.655
# - Train Entropy: 0.6932229
# - Val Entropy: 0.6932385
# Epoch: 3
# Epoch 3 | Batch 1 / 8
# Epoch 3 | Batch 2 / 8
# Epoch 3 | Batch 3 / 8
# Epoch 3 | Batch 4 / 8
# Epoch 3 | Batch 5 / 8
# Epoch 3 | Batch 6 / 8
# Epoch 3 | Batch 7 / 8
# Epoch 3 | Batch 8 / 8
# Epoch 3 / 30:
# - Train MSE: 0.008293711
# - Val MSE: 0.009383492
# - Train Loss: 8.3556725e6
# - Val Loss: -850.6482
# - Train Entropy: 0.6939517
# - Val Entropy: 0.69441766
# Epoch: 4
# Epoch 4 | Batch 1 / 8
# Epoch 4 | Batch 2 / 8
# Epoch 4 | Batch 3 / 8
# Epoch 4 | Batch 4 / 8
# Epoch 4 | Batch 5 / 8
# Epoch 4 | Batch 6 / 8
# Epoch 4 | Batch 7 / 8
# Epoch 4 | Batch 8 / 8
# Epoch 4 / 30:
# - Train MSE: 0.008261885
# - Val MSE: 0.009589146
# - Train Loss: 927607.1
# - Val Loss: -916.4106
# - Train Entropy: 0.69439447
# - Val Entropy: 0.6955635
# Epoch: 5
# Epoch 5 | Batch 1 / 8
# Epoch 5 | Batch 2 / 8
# Epoch 5 | Batch 3 / 8
# Epoch 5 | Batch 4 / 8
# Epoch 5 | Batch 5 / 8
# Epoch 5 | Batch 6 / 8
# Epoch 5 | Batch 7 / 8
# Epoch 5 | Batch 8 / 8
# Epoch 5 / 30:
# - Train MSE: 0.008251661
# - Val MSE: 0.009485456
# - Train Loss: 11230.525
# - Val Loss: -915.4454
# - Train Entropy: 0.6946794
# - Val Entropy: 0.69592315
# Epoch: 6
# Epoch 6 | Batch 1 / 8
# Epoch 6 | Batch 2 / 8
# Epoch 6 | Batch 3 / 8
# Epoch 6 | Batch 4 / 8
# Epoch 6 | Batch 5 / 8
# Epoch 6 | Batch 6 / 8
# Epoch 6 | Batch 7 / 8
# Epoch 6 | Batch 8 / 8
# Epoch 6 / 30:
# - Train MSE: 0.008160613
# - Val MSE: 0.0093708
# - Train Loss: -295.7373
# - Val Loss: -928.1729
# - Train Entropy: 0.6945265
# - Val Entropy: 0.6958567
# Epoch: 7
# Epoch 7 | Batch 1 / 8
# Epoch 7 | Batch 2 / 8
# Epoch 7 | Batch 3 / 8
# Epoch 7 | Batch 4 / 8
# Epoch 7 | Batch 5 / 8
# Epoch 7 | Batch 6 / 8
# Epoch 7 | Batch 7 / 8
# Epoch 7 | Batch 8 / 8
# Epoch 7 / 30:
# - Train MSE: 0.008201315
# - Val MSE: 0.009513555
# - Train Loss: -1990.232
# - Val Loss: -920.3308
# - Train Entropy: 0.69489187
# - Val Entropy: 0.6964351
# Epoch: 8
# Epoch 8 | Batch 1 / 8
# Epoch 8 | Batch 2 / 8
# Epoch 8 | Batch 3 / 8
# Epoch 8 | Batch 4 / 8
# Epoch 8 | Batch 5 / 8
# Epoch 8 | Batch 6 / 8
# Epoch 8 | Batch 7 / 8
# Epoch 8 | Batch 8 / 8
# Epoch 8 / 30:
# - Train MSE: 0.008129995
# - Val MSE: 0.009366815
# - Train Loss: -2187.5024
# - Val Loss: -988.3992
# - Train Entropy: 0.6945378
# - Val Entropy: 0.6960069
# Epoch: 9
# Epoch 9 | Batch 1 / 8
# Epoch 9 | Batch 2 / 8
# Epoch 9 | Batch 3 / 8
# Epoch 9 | Batch 4 / 8
# Epoch 9 | Batch 5 / 8
# Epoch 9 | Batch 6 / 8
# Epoch 9 | Batch 7 / 8
# Epoch 9 | Batch 8 / 8
# Epoch 9 / 30:
# - Train MSE: 0.008147276
# - Val MSE: 0.009793588
# - Train Loss: -2318.8408
# - Val Loss: -854.21234
# - Train Entropy: 0.6950441
# - Val Entropy: 0.6976813
# Epoch: 10
# Epoch 10 | Batch 1 / 8
# Epoch 10 | Batch 2 / 8
# Epoch 10 | Batch 3 / 8
# Epoch 10 | Batch 4 / 8
# Epoch 10 | Batch 5 / 8
# Epoch 10 | Batch 6 / 8
# Epoch 10 | Batch 7 / 8
# Epoch 10 | Batch 8 / 8
# Epoch 10 / 30:
# - Train MSE: 0.008077735
# - Val MSE: 0.009330872
# - Train Loss: -2379.218
# - Val Loss: -1002.0757
# - Train Entropy: 0.69459254
# - Val Entropy: 0.6962628
# Epoch: 11
# Epoch 11 | Batch 1 / 8
# Epoch 11 | Batch 2 / 8
# Epoch 11 | Batch 3 / 8
# Epoch 11 | Batch 4 / 8
# Epoch 11 | Batch 5 / 8
# Epoch 11 | Batch 6 / 8
# Epoch 11 | Batch 7 / 8
# Epoch 11 | Batch 8 / 8
# Epoch 11 / 30:
# - Train MSE: 0.008050664
# - Val MSE: 0.009321068
# - Train Loss: -2457.5015
# - Val Loss: -1001.37756
# - Train Entropy: 0.6946427
# - Val Entropy: 0.69633985
# Epoch: 12
# Epoch 12 | Batch 1 / 8
# Epoch 12 | Batch 2 / 8
# Epoch 12 | Batch 3 / 8
# Epoch 12 | Batch 4 / 8
# Epoch 12 | Batch 5 / 8
# Epoch 12 | Batch 6 / 8
# Epoch 12 | Batch 7 / 8
# Epoch 12 | Batch 8 / 8
# Epoch 12 / 30:
# - Train MSE: 0.008101686
# - Val MSE: 0.00970409
# - Train Loss: -2532.5156
# - Val Loss: -945.3237
# - Train Entropy: 0.69513845
# - Val Entropy: 0.6976604
# Epoch: 13
# Epoch 13 | Batch 1 / 8
# Epoch 13 | Batch 2 / 8
# Epoch 13 | Batch 3 / 8
# Epoch 13 | Batch 4 / 8
# Epoch 13 | Batch 5 / 8
# Epoch 13 | Batch 6 / 8
# Epoch 13 | Batch 7 / 8
# Epoch 13 | Batch 8 / 8
# Epoch 13 / 30:
# - Train MSE: 0.008003458
# - Val MSE: 0.00924084
# - Train Loss: -2589.8
# - Val Loss: -992.5095
# - Train Entropy: 0.6944072
# - Val Entropy: 0.69620764
# Epoch: 14
# Epoch 14 | Batch 1 / 8
# Epoch 14 | Batch 2 / 8
# Epoch 14 | Batch 3 / 8
# Epoch 14 | Batch 4 / 8
# Epoch 14 | Batch 5 / 8
# Epoch 14 | Batch 6 / 8
# Epoch 14 | Batch 7 / 8
# Epoch 14 | Batch 8 / 8
# Epoch 14 / 30:
# - Train MSE: 0.008043965
# - Val MSE: 0.009536009
# - Train Loss: -2630.0132
# - Val Loss: -882.64667
# - Train Entropy: 0.6951654
# - Val Entropy: 0.69725907
# Epoch: 15
# Epoch 15 | Batch 1 / 8
# Epoch 15 | Batch 2 / 8
# Epoch 15 | Batch 3 / 8
# Epoch 15 | Batch 4 / 8
# Epoch 15 | Batch 5 / 8
# Epoch 15 | Batch 6 / 8
# Epoch 15 | Batch 7 / 8
# Epoch 15 | Batch 8 / 8
# Epoch 15 / 30:
# - Train MSE: 0.00801428
# - Val MSE: 0.0091628125
# - Train Loss: -2674.9097
# - Val Loss: -1006.4333
# - Train Entropy: 0.6949143
# - Val Entropy: 0.69577146
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# ...
# - Train MSE: 0.05078593
# - Val MSE: 0.054601952
# - Train Loss: 5527.265
# - Val Loss: 5438.768
# - Train Entropy: 0.74109524
# - Val Entropy: 0.75218695
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# Epoch 16 | Batch 3 / 8
# Epoch 16 | Batch 4 / 8
# Epoch 16 | Batch 5 / 8
# Epoch 16 | Batch 6 / 8
# Epoch 16 | Batch 7 / 8
# Epoch 16 | Batch 8 / 8
# Epoch 16 / 30:
# - Train MSE: 0.052618403
# - Val MSE: 0.05444757
# - Train Loss: 5628.9175
# - Val Loss: 5543.9546
# - Train Entropy: 0.73008776
# - Val Entropy: 0.7409707
# Epoch: 17
# Epoch 17 | Batch 1 / 8
# Epoch 17 | Batch 2 / 8
# Epoch 17 | Batch 3 / 8
# Epoch 17 | Batch 4 / 8
# Epoch 17 | Batch 5 / 8
# Epoch 17 | Batch 6 / 8
# Epoch 17 | Batch 7 / 8
# Epoch 17 | Batch 8 / 8
# Epoch 17 / 30:
# - Train MSE: 0.0510568
# - Val MSE: 0.052829046
# - Train Loss: 5547.0996
# - Val Loss: 5472.4688
# - Train Entropy: 0.7322933
# - Val Entropy: 0.74376184
# Epoch: 18
# Epoch 18 | Batch 1 / 8
# Epoch 18 | Batch 2 / 8
# Epoch 18 | Batch 3 / 8
# Epoch 18 | Batch 4 / 8
# Epoch 18 | Batch 5 / 8
# Epoch 18 | Batch 6 / 8
# Epoch 18 | Batch 7 / 8
# Epoch 18 | Batch 8 / 8
# Epoch 18 / 30:
# - Train MSE: 0.05079196
# - Val MSE: 0.053328402
# - Train Loss: 5512.817
# - Val Loss: 5448.4224
# - Train Entropy: 0.73532116
# - Val Entropy: 0.74465233
# Epoch: 19
# Epoch 19 | Batch 1 / 8
# Epoch 19 | Batch 2 / 8
# Epoch 19 | Batch 3 / 8
# Epoch 19 | Batch 4 / 8
# Epoch 19 | Batch 5 / 8
# Epoch 19 | Batch 6 / 8
# Epoch 19 | Batch 7 / 8
# Epoch 19 | Batch 8 / 8
# Epoch 19 / 30:
# - Train MSE: 0.051197622
# - Val MSE: 0.054166857
# - Train Loss: 5576.107
# - Val Loss: 5463.7725
# - Train Entropy: 0.7325702
# - Val Entropy: 0.74316263
# Epoch: 20
# Epoch 20 | Batch 1 / 8
# Epoch 20 | Batch 2 / 8
# Epoch 20 | Batch 3 / 8
# Epoch 20 | Batch 4 / 8
# Epoch 20 | Batch 5 / 8
# Epoch 20 | Batch 6 / 8
# Epoch 20 | Batch 7 / 8
# Epoch 20 | Batch 8 / 8
# Epoch 20 / 30:
# - Train MSE: 0.049971797
# - Val MSE: 0.053008497
# - Train Loss: 5476.568
# - Val Loss: 5427.092
# - Train Entropy: 0.7353619
# - Val Entropy: 0.7449246
# Epoch: 21
# Epoch 21 | Batch 1 / 8
# Epoch 21 | Batch 2 / 8
# Epoch 21 | Batch 3 / 8
# Epoch 21 | Batch 4 / 8
# Epoch 21 | Batch 5 / 8
# Epoch 21 | Batch 6 / 8
# Epoch 21 | Batch 7 / 8
# Epoch 21 | Batch 8 / 8
# Epoch 21 / 30:
# - Train MSE: 0.049737263
# - Val MSE: 0.053666607
# - Train Loss: 5452.659
# - Val Loss: 5487.699
# - Train Entropy: 0.73863196
# - Val Entropy: 0.7485443
# Epoch: 22
# Epoch 22 | Batch 1 / 8
# Epoch 22 | Batch 2 / 8
# Epoch 22 | Batch 3 / 8
# Epoch 22 | Batch 4 / 8
# Epoch 22 | Batch 5 / 8
# Epoch 22 | Batch 6 / 8
# Epoch 22 | Batch 7 / 8
# Epoch 22 | Batch 8 / 8
# Epoch 22 / 30:
# - Train MSE: 0.049609013
# - Val MSE: 0.053262174
# - Train Loss: 5429.1367
# - Val Loss: 5393.347
# - Train Entropy: 0.73519456
# - Val Entropy: 0.7467944
# Epoch: 23
# Epoch 23 | Batch 1 / 8
# Epoch 23 | Batch 2 / 8
# Epoch 23 | Batch 3 / 8
# Epoch 23 | Batch 4 / 8
# Epoch 23 | Batch 5 / 8
# Epoch 23 | Batch 6 / 8
# Epoch 23 | Batch 7 / 8
# Epoch 23 | Batch 8 / 8
# Epoch 23 / 30:
# - Train MSE: 0.04987649
# - Val MSE: 0.053238064
# - Train Loss: 5444.0015
# - Val Loss: 5433.896
# - Train Entropy: 0.732771
# - Val Entropy: 0.7460974
# Epoch: 24
# Epoch 24 | Batch 1 / 8
# Epoch 24 | Batch 2 / 8
# Epoch 24 | Batch 3 / 8
# Epoch 24 | Batch 4 / 8
# Epoch 24 | Batch 5 / 8
# Epoch 24 | Batch 6 / 8
# Epoch 24 | Batch 7 / 8
# Epoch 24 | Batch 8 / 8
# Epoch 24 / 30:
# - Train MSE: 0.048821352
# - Val MSE: 0.052721705
# - Train Loss: 5385.5884
# - Val Loss: 5364.386
# - Train Entropy: 0.7399946
# - Val Entropy: 0.7496601
# Epoch: 25
# Epoch 25 | Batch 1 / 8
# Epoch 25 | Batch 2 / 8
# Epoch 25 | Batch 3 / 8
# Epoch 25 | Batch 4 / 8
# Epoch 25 | Batch 5 / 8
# Epoch 25 | Batch 6 / 8
# Epoch 25 | Batch 7 / 8
# Epoch 25 | Batch 8 / 8
# Epoch 25 / 30:
# - Train MSE: 0.0497016
# - Val MSE: 0.05804354
# - Train Loss: 5399.7173
# - Val Loss: 5586.954
# - Train Entropy: 0.7452969
# - Val Entropy: 0.75703603
# Epoch: 26
# Epoch 26 | Batch 1 / 8
# Epoch 26 | Batch 2 / 8
# Epoch 26 | Batch 3 / 8
# Epoch 26 | Batch 4 / 8
# Epoch 26 | Batch 5 / 8
# Epoch 26 | Batch 6 / 8
# Epoch 26 | Batch 7 / 8
# Epoch 26 | Batch 8 / 8
# Epoch 26 / 30:
# - Train MSE: 0.048485976
# - Val MSE: 0.055457503
# - Train Loss: 5344.6885
# - Val Loss: 5571.2285
# - Train Entropy: 0.7414715
# - Val Entropy: 0.7504413
# Epoch: 27
# Epoch 27 | Batch 1 / 8
# Epoch 27 | Batch 2 / 8
# Epoch 27 | Batch 3 / 8
# Epoch 27 | Batch 4 / 8
# Epoch 27 | Batch 5 / 8
# Epoch 27 | Batch 6 / 8
# Epoch 27 | Batch 7 / 8
# Epoch 27 | Batch 8 / 8
# Epoch 27 / 30:
# - Train MSE: 0.04747813
# - Val MSE: 0.053510398
# - Train Loss: 5301.81
# - Val Loss: 5470.981
# - Train Entropy: 0.738938
# - Val Entropy: 0.7491269
# Epoch: 28
# Epoch 28 | Batch 1 / 8
# Epoch 28 | Batch 2 / 8
# Epoch 28 | Batch 3 / 8
# Epoch 28 | Batch 4 / 8
# Epoch 28 | Batch 5 / 8
# Epoch 28 | Batch 6 / 8
# Epoch 28 | Batch 7 / 8
# Epoch 28 | Batch 8 / 8
# Epoch 28 / 30:
# - Train MSE: 0.046981346
# - Val MSE: 0.052541997
# - Train Loss: 5263.6733
# - Val Loss: 5376.854
# - Train Entropy: 0.7358702
# - Val Entropy: 0.7451623
# Epoch: 29
# Epoch 29 | Batch 1 / 8
# Epoch 29 | Batch 2 / 8
# Epoch 29 | Batch 3 / 8
# Epoch 29 | Batch 4 / 8
# Epoch 29 | Batch 5 / 8
# Epoch 29 | Batch 6 / 8
# Epoch 29 | Batch 7 / 8
# Epoch 29 | Batch 8 / 8
# Epoch 29 / 30:
# - Train MSE: 0.04589579
# - Val MSE: 0.05226574
# - Train Loss: 5191.2207
# - Val Loss: 5357.085
# - Train Entropy: 0.7373969
# - Val Entropy: 0.7486102
# Epoch: 30
# Epoch 30 | Batch 1 / 8
# Epoch 30 | Batch 2 / 8
# Epoch 30 | Batch 3 / 8
# Epoch 30 | Batch 4 / 8
# Epoch 30 | Batch 5 / 8
# Epoch 30 | Batch 6 / 8
# Epoch 30 | Batch 7 / 8
# Epoch 30 | Batch 8 / 8
# Epoch 30 / 30:
# - Train MSE: 0.045964103
# - Val MSE: 0.051884882
# - Train Loss: 5167.947
# - Val Loss: 5387.6523
# - Train Entropy: 0.7389617
# - Val Entropy: 0.7456357
#   Latent Dim: 100
# Using GPU for training.
# Epoch: 1
# Epoch 1 | Batch 1 / 8
# Epoch 1 | Batch 2 / 8
# Epoch 1 | Batch 3 / 8
# Epoch 1 | Batch 4 / 8
# Epoch 1 | Batch 5 / 8
# Epoch 1 | Batch 6 / 8
# Epoch 1 | Batch 7 / 8
# Epoch 1 | Batch 8 / 8
# Epoch 1 / 30:
# - Train MSE: 0.12505375
# - Val MSE: 0.11145396
# - Train Loss: 663586.6
# - Val Loss: 10180.427
# - Train Entropy: 0.7990694
# - Val Entropy: 0.8198362
# Epoch: 2
# Epoch 2 | Batch 1 / 8
# Epoch 2 | Batch 2 / 8
# Epoch 2 | Batch 3 / 8
# Epoch 2 | Batch 4 / 8
# Epoch 2 | Batch 5 / 8
# Epoch 2 | Batch 6 / 8
# Epoch 2 | Batch 7 / 8
# Epoch 2 | Batch 8 / 8
# Epoch 2 / 30:
# - Train MSE: 0.082768016
# - Val MSE: 0.07976536
# - Train Loss: 8577.046
# - Val Loss: 6400.359
# - Train Entropy: 0.77572685
# - Val Entropy: 0.7944691
# Epoch: 3
# Epoch 3 | Batch 1 / 8
# Epoch 3 | Batch 2 / 8
# Epoch 3 | Batch 3 / 8
# Epoch 3 | Batch 4 / 8
# Epoch 3 | Batch 5 / 8
# Epoch 3 | Batch 6 / 8
# Epoch 3 | Batch 7 / 8
# Epoch 3 | Batch 8 / 8
# Epoch 3 / 30:
# - Train MSE: 0.07482689
# - Val MSE: 0.07541202
# - Train Loss: 6704.4404
# - Val Loss: 6208.018
# - Train Entropy: 0.77447516
# - Val Entropy: 0.7959113
# Epoch: 4
# Epoch 4 | Batch 1 / 8
# Epoch 4 | Batch 2 / 8
# Epoch 4 | Batch 3 / 8
# Epoch 4 | Batch 4 / 8
# Epoch 4 | Batch 5 / 8
# Epoch 4 | Batch 6 / 8
# Epoch 4 | Batch 7 / 8
# Epoch 4 | Batch 8 / 8
# Epoch 4 / 30:
# - Train MSE: 0.07012921
# - Val MSE: 0.0655689
# - Train Loss: 6678.5493
# - Val Loss: 5938.3877
# - Train Entropy: 0.75944406
# - Val Entropy: 0.7779329
# Epoch: 5
# Epoch 5 | Batch 1 / 8
# Epoch 5 | Batch 2 / 8
# Epoch 5 | Batch 3 / 8
# Epoch 5 | Batch 4 / 8
# Epoch 5 | Batch 5 / 8
# Epoch 5 | Batch 6 / 8
# Epoch 5 | Batch 7 / 8
# Epoch 5 | Batch 8 / 8
# Epoch 5 / 30:
# - Train MSE: 0.06920586
# - Val MSE: 0.06204005
# - Train Loss: 6759.9077
# - Val Loss: 5822.9126
# - Train Entropy: 0.75003636
# - Val Entropy: 0.76768464
# Epoch: 6
# Epoch 6 | Batch 1 / 8
# Epoch 6 | Batch 2 / 8
# Epoch 6 | Batch 3 / 8
# Epoch 6 | Batch 4 / 8
# Epoch 6 | Batch 5 / 8
# Epoch 6 | Batch 6 / 8
# Epoch 6 | Batch 7 / 8
# Epoch 6 | Batch 8 / 8
# Epoch 6 / 30:
# - Train MSE: 0.0674592
# - Val MSE: 0.064010195
# - Train Loss: 6573.808
# - Val Loss: 5816.545
# - Train Entropy: 0.7567207
# - Val Entropy: 0.77672666
# Epoch: 7
# Epoch 7 | Batch 1 / 8
# Epoch 7 | Batch 2 / 8
# Epoch 7 | Batch 3 / 8
# Epoch 7 | Batch 4 / 8
# Epoch 7 | Batch 5 / 8
# Epoch 7 | Batch 6 / 8
# Epoch 7 | Batch 7 / 8
# Epoch 7 | Batch 8 / 8
# Epoch 7 / 30:
# - Train MSE: 0.08950398
# - Val MSE: 0.08961126
# - Train Loss: 7224.2715
# - Val Loss: 6769.5303
# - Train Entropy: 0.7972692
# - Val Entropy: 0.81438416
# Epoch: 8
# Epoch 8 | Batch 1 / 8
# Epoch 8 | Batch 2 / 8
# Epoch 8 | Batch 3 / 8
# Epoch 8 | Batch 4 / 8
# Epoch 8 | Batch 5 / 8
# Epoch 8 | Batch 6 / 8
# Epoch 8 | Batch 7 / 8
# Epoch 8 | Batch 8 / 8
# Epoch 8 / 30:
# - Train MSE: 0.07131299
# - Val MSE: 0.07280414
# - Train Loss: 6572.851
# - Val Loss: 6243.3066
# - Train Entropy: 0.77551633
# - Val Entropy: 0.7938055
# Epoch: 9
# Epoch 9 | Batch 1 / 8
# Epoch 9 | Batch 2 / 8
# Epoch 9 | Batch 3 / 8
# Epoch 9 | Batch 4 / 8
# Epoch 9 | Batch 5 / 8
# Epoch 9 | Batch 6 / 8
# Epoch 9 | Batch 7 / 8
# Epoch 9 | Batch 8 / 8
# Epoch 9 / 30:
# - Train MSE: 0.08598573
# - Val MSE: 0.095503345
# - Train Loss: 6949.322
# - Val Loss: 6799.986
# - Train Entropy: 0.8014753
# - Val Entropy: 0.8213039
# Epoch: 10
# Epoch 10 | Batch 1 / 8
# Epoch 10 | Batch 2 / 8
# Epoch 10 | Batch 3 / 8
# Epoch 10 | Batch 4 / 8
# Epoch 10 | Batch 5 / 8
# Epoch 10 | Batch 6 / 8
# Epoch 10 | Batch 7 / 8
# Epoch 10 | Batch 8 / 8
# Epoch 10 / 30:
# - Train MSE: 0.07931812
# - Val MSE: 0.09335935
# - Train Loss: 6799.8745
# - Val Loss: 6552.377
# - Train Entropy: 0.7930692
# - Val Entropy: 0.818997
# Epoch: 11
# Epoch 11 | Batch 1 / 8
# Epoch 11 | Batch 2 / 8
# Epoch 11 | Batch 3 / 8
# Epoch 11 | Batch 4 / 8
# Epoch 11 | Batch 5 / 8
# Epoch 11 | Batch 6 / 8
# Epoch 11 | Batch 7 / 8
# Epoch 11 | Batch 8 / 8
# Epoch 11 / 30:
# - Train MSE: 0.0664398
# - Val MSE: 0.060459767
# - Train Loss: 6611.2036
# - Val Loss: 5862.061
# - Train Entropy: 0.7505889
# - Val Entropy: 0.7682869
# Epoch: 12
# Epoch 12 | Batch 1 / 8
# Epoch 12 | Batch 2 / 8
# Epoch 12 | Batch 3 / 8
# Epoch 12 | Batch 4 / 8
# Epoch 12 | Batch 5 / 8
# Epoch 12 | Batch 6 / 8
# Epoch 12 | Batch 7 / 8
# Epoch 12 | Batch 8 / 8
# Epoch 12 / 30:
# - Train MSE: 0.06609148
# - Val MSE: 0.06590056
# - Train Loss: 6472.1294
# - Val Loss: 5985.635
# - Train Entropy: 0.7621572
# - Val Entropy: 0.78167284
# Epoch: 13
# Epoch 13 | Batch 1 / 8
# Epoch 13 | Batch 2 / 8
# Epoch 13 | Batch 3 / 8
# Epoch 13 | Batch 4 / 8
# Epoch 13 | Batch 5 / 8
# Epoch 13 | Batch 6 / 8
# Epoch 13 | Batch 7 / 8
# Epoch 13 | Batch 8 / 8
# Epoch 13 / 30:
# - Train MSE: 0.06993406
# - Val MSE: 0.07726771
# - Train Loss: 6548.8037
# - Val Loss: 6247.2817
# - Train Entropy: 0.7783643
# - Val Entropy: 0.80064106
# Epoch: 14
# Epoch 14 | Batch 1 / 8
# Epoch 14 | Batch 2 / 8
# Epoch 14 | Batch 3 / 8
# Epoch 14 | Batch 4 / 8
# Epoch 14 | Batch 5 / 8
# Epoch 14 | Batch 6 / 8
# Epoch 14 | Batch 7 / 8
# Epoch 14 | Batch 8 / 8
# Epoch 14 / 30:
# - Train MSE: 0.0658232
# - Val MSE: 0.06970431
# - Train Loss: 6402.01
# - Val Loss: 6022.0625
# - Train Entropy: 0.76798964
# - Val Entropy: 0.788979
# Epoch: 15
# Epoch 15 | Batch 1 / 8
# Epoch 15 | Batch 2 / 8
# Epoch 15 | Batch 3 / 8
# Epoch 15 | Batch 4 / 8
# Epoch 15 | Batch 5 / 8
# Epoch 15 | Batch 6 / 8
# Epoch 15 | Batch 7 / 8
# Epoch 15 | Batch 8 / 8
# Epoch 15 / 30:
# - Train MSE: 0.071544625
# - Val MSE: 0.078002244
# - Train Loss: 6654.297
# - Val Loss: 6383.186
# - Train Entropy: 0.7833049
# - Val Entropy: 0.8025825
# Epoch: 16
# Epoch 16 | Batch 1 / 8
# Epoch 16 | Batch 2 / 8
# Epoch 16 | Batch 3 / 8
# Epoch 16 | Batch 4 / 8
# Epoch 16 | Batch 5 / 8
# Epoch 16 | Batch 6 / 8
# Epoch 16 | Batch 7 / 8
# Epoch 16 | Batch 8 / 8
# Epoch 16 / 30:
# - Train MSE: 0.06768466
# - Val MSE: 0.074200116
# - Train Loss: 6456.9395
# - Val Loss: 6204.24
# - Train Entropy: 0.77801365
# - Val Entropy: 0.79758227
# Epoch: 17
# Epoch 17 | Batch 1 / 8
# Epoch 17 | Batch 2 / 8
# Epoch 17 | Batch 3 / 8
# Epoch 17 | Batch 4 / 8
# Epoch 17 | Batch 5 / 8
# Epoch 17 | Batch 6 / 8
# Epoch 17 | Batch 7 / 8
# Epoch 17 | Batch 8 / 8
# Epoch 17 / 30:
# - Train MSE: 0.06938232
# - Val MSE: 0.0784427
# - Train Loss: 6529.0073
# - Val Loss: 6317.4585
# - Train Entropy: 0.78164065
# - Val Entropy: 0.80288684
# Epoch: 18
# Epoch 18 | Batch 1 / 8
# Epoch 18 | Batch 2 / 8
# Epoch 18 | Batch 3 / 8
# Epoch 18 | Batch 4 / 8
# Epoch 18 | Batch 5 / 8
# Epoch 18 | Batch 6 / 8
# Epoch 18 | Batch 7 / 8
# Epoch 18 | Batch 8 / 8
# Epoch 18 / 30:
# - Train MSE: 0.060008116
# - Val MSE: 0.057732347
# - Train Loss: 6205.072
# - Val Loss: 5708.3887
# - Train Entropy: 0.74720895
# - Val Entropy: 0.7656918
# Epoch: 19
# Epoch 19 | Batch 1 / 8
# Epoch 19 | Batch 2 / 8
# Epoch 19 | Batch 3 / 8
# Epoch 19 | Batch 4 / 8
# Epoch 19 | Batch 5 / 8
# Epoch 19 | Batch 6 / 8
# Epoch 19 | Batch 7 / 8
# Epoch 19 | Batch 8 / 8
# Epoch 19 / 30:
# - Train MSE: 0.060446583
# - Val MSE: 0.055547703
# - Train Loss: 6221.1006
# - Val Loss: 5616.1396
# - Train Entropy: 0.73814076
# - Val Entropy: 0.7560934
# Epoch: 20
# Epoch 20 | Batch 1 / 8
# Epoch 20 | Batch 2 / 8
# Epoch 20 | Batch 3 / 8
# Epoch 20 | Batch 4 / 8
# Epoch 20 | Batch 5 / 8
# Epoch 20 | Batch 6 / 8
# Epoch 20 | Batch 7 / 8
# Epoch 20 | Batch 8 / 8
# Epoch 20 / 30:
# - Train MSE: 0.055460375
# - Val MSE: 0.05537544
# - Train Loss: 6258.7437
# - Val Loss: 5697.979
# - Train Entropy: 0.7468169
# - Val Entropy: 0.7589892
# Epoch: 21
# Epoch 21 | Batch 1 / 8
# Epoch 21 | Batch 2 / 8
# Epoch 21 | Batch 3 / 8
# Epoch 21 | Batch 4 / 8
# Epoch 21 | Batch 5 / 8
# Epoch 21 | Batch 6 / 8
# Epoch 21 | Batch 7 / 8
# Epoch 21 | Batch 8 / 8
# Epoch 21 / 30:
# - Train MSE: 0.060435258
# - Val MSE: 0.05470272
# - Train Loss: 6256.5044
# - Val Loss: 5625.0293
# - Train Entropy: 0.73036903
# - Val Entropy: 0.7439264
# Epoch: 22
# Epoch 22 | Batch 1 / 8
# Epoch 22 | Batch 2 / 8
# Epoch 22 | Batch 3 / 8
# Epoch 22 | Batch 4 / 8
# Epoch 22 | Batch 5 / 8
# Epoch 22 | Batch 6 / 8
# Epoch 22 | Batch 7 / 8
# Epoch 22 | Batch 8 / 8
# Epoch 22 / 30:
# - Train MSE: 0.0543686
# - Val MSE: 0.05359625
# - Train Loss: 5965.062
# - Val Loss: 5571.6494
# - Train Entropy: 0.7370405
# - Val Entropy: 0.7512947
# Epoch: 23
# Epoch 23 | Batch 1 / 8
# Epoch 23 | Batch 2 / 8
# Epoch 23 | Batch 3 / 8
# Epoch 23 | Batch 4 / 8
# Epoch 23 | Batch 5 / 8
# Epoch 23 | Batch 6 / 8
# Epoch 23 | Batch 7 / 8
# Epoch 23 | Batch 8 / 8
# Epoch 23 / 30:
# - Train MSE: 0.08355839
# - Val MSE: 0.0940978
# - Train Loss: 7729.3276
# - Val Loss: 6587.181
# - Train Entropy: 0.7887759
# - Val Entropy: 0.81287855
# Epoch: 24
# Epoch 24 | Batch 1 / 8
# Epoch 24 | Batch 2 / 8
# Epoch 24 | Batch 3 / 8
# Epoch 24 | Batch 4 / 8
# Epoch 24 | Batch 5 / 8
# Epoch 24 | Batch 6 / 8
# Epoch 24 | Batch 7 / 8
# Epoch 24 | Batch 8 / 8
# Epoch 24 / 30:
# - Train MSE: 0.05903564
# - Val MSE: 0.064112455
# - Train Loss: 6028.032
# - Val Loss: 5906.599
# - Train Entropy: 0.7561384
# - Val Entropy: 0.7710706
# Epoch: 25
# Epoch 25 | Batch 1 / 8
# Epoch 25 | Batch 2 / 8
# Epoch 25 | Batch 3 / 8
# Epoch 25 | Batch 4 / 8
# Epoch 25 | Batch 5 / 8
# Epoch 25 | Batch 6 / 8
# Epoch 25 | Batch 7 / 8
# Epoch 25 | Batch 8 / 8
# Epoch 25 / 30:
# - Train MSE: 0.053832505
# - Val MSE: 0.05396701
# - Train Loss: 5914.1025
# - Val Loss: 5642.9473
# - Train Entropy: 0.7391063
# - Val Entropy: 0.7525634
# Epoch: 26
# Epoch 26 | Batch 1 / 8
# Epoch 26 | Batch 2 / 8
# Epoch 26 | Batch 3 / 8
# Epoch 26 | Batch 4 / 8
# Epoch 26 | Batch 5 / 8
# Epoch 26 | Batch 6 / 8
# Epoch 26 | Batch 7 / 8
# Epoch 26 | Batch 8 / 8
# Epoch 26 / 30:
# - Train MSE: 0.05158593
# - Val MSE: 0.05454751
# - Train Loss: 5781.4326
# - Val Loss: 5600.998
# - Train Entropy: 0.74556714
# - Val Entropy: 0.7589558
# Epoch: 27
# Epoch 27 | Batch 1 / 8
# Epoch 27 | Batch 2 / 8
# Epoch 27 | Batch 3 / 8
# Epoch 27 | Batch 4 / 8
# Epoch 27 | Batch 5 / 8
# Epoch 27 | Batch 6 / 8
# Epoch 27 | Batch 7 / 8
# Epoch 27 | Batch 8 / 8
# Epoch 27 / 30:
# - Train MSE: 0.05130116
# - Val MSE: 0.054769248
# - Train Loss: 5758.363
# - Val Loss: 5638.5767
# - Train Entropy: 0.7470119
# - Val Entropy: 0.76008373
# Epoch: 28
# Epoch 28 | Batch 1 / 8
# Epoch 28 | Batch 2 / 8
# Epoch 28 | Batch 3 / 8
# Epoch 28 | Batch 4 / 8
# Epoch 28 | Batch 5 / 8
# Epoch 28 | Batch 6 / 8
# Epoch 28 | Batch 7 / 8
# Epoch 28 | Batch 8 / 8
# Epoch 28 / 30:
# - Train MSE: 0.0507356
# - Val MSE: 0.053452194
# - Train Loss: 5673.6045
# - Val Loss: 5563.3594
# - Train Entropy: 0.7469654
# - Val Entropy: 0.7550525
# Epoch: 29
# Epoch 29 | Batch 1 / 8
# Epoch 29 | Batch 2 / 8
# Epoch 29 | Batch 3 / 8
# Epoch 29 | Batch 4 / 8
# Epoch 29 | Batch 5 / 8
# Epoch 29 | Batch 6 / 8
# Epoch 29 | Batch 7 / 8
# Epoch 29 | Batch 8 / 8
# Epoch 29 / 30:
# - Train MSE: 0.049689133
# - Val MSE: 0.05351229
# - Train Loss: 5591.4434
# - Val Loss: 5572.8784
# - Train Entropy: 0.7411823
# - Val Entropy: 0.75276315
# Epoch: 30
# Epoch 30 | Batch 1 / 8
# Epoch 30 | Batch 2 / 8
# Epoch 30 | Batch 3 / 8
# Epoch 30 | Batch 4 / 8
# Epoch 30 | Batch 5 / 8
# Epoch 30 | Batch 6 / 8
# Epoch 30 | Batch 7 / 8
# Epoch 30 | Batch 8 / 8
# Epoch 30 / 30:
# - Train MSE: 0.048825692
# - Val MSE: 0.053357
# - Train Loss: 5526.7773
# - Val Loss: 5598.0156
# - Train Entropy: 0.7387908
# - Val Entropy: 0.74855024

# %% [markdown]
# Run dimensionality reducation and clustering based on experiemntal parameters specified above

# %%
results, grouped, all_results = evaluate_dimensionality_reduction(
    dims_list,
    data_sources,
    methods,
    repeats,
    clustering_methods,
    vae_results,
    group_array,
    select_counts
)

# Access results:
display(results)  # Summary DataFrame
# === Summary Results DataFrame ===
# This DataFrame contains one row per configuration tested across the pipeline.
# It summarizes the clustering performance after dimensionality reduction.

# Columns:
# - Data        :: String   → Name of the dataset ("RDCM", "FC", etc.)
# - Method      :: String   → Dimensionality reduction method used ("PCA", "tSNE", "VAE")
# - Dims        :: Int64    → Latent dimension size
# - Clustering  :: String   → Clustering algorithm used ("kmeans", "fuzzy", "hierarchical")
# - MeanAcc     :: Float64  → Mean accuracy across repeats
# - StdAcc      :: Float64  → Standard deviation of accuracy

# Example:
# Row	   Data	   Method	Dims	Clustering	  MeanAcc   StdAcc
# 1	  RDCM	PCA	    2	    kmeans	      0.413667	0.0285
# 2	  RDCM	PCA	    2	    fuzzy	        0.408333	0.0176
# 3	  RDCM	PCA	    2	    hierarchical	0.413333	0.0276
# 4	  RDCM	tSNE	  2	    kmeans	      0.413000	0.0309
# Out:
# UndefVarError: `transform` not defined in `Main`
#
# Hint: It looks like two or more modules export different bindings with this name, resulting in ambiguity. Try explicitly importing it from a particular module, or qualifying the name with the module it should come from.
#
# Hint: a global variable of this name also exists in DataFrames.
#
# Hint: a global variable of this name may be made accessible by importing ScikitLearnBase in the current active module Main
#
# Hint: a global variable of this name also exists in MultivariateStats.
#
#
#
# Stacktrace:
#
#  [1] run_pca(connectivity_matrix::Matrix{Float64}; dims::Int64)
#
#    @ Main g:\Lyubov\TNM_project\utils_clustering.jl:125
#
#  [2] run_pca
#
#    @ g:\Lyubov\TNM_project\utils_clustering.jl:119 [inlined]
#
#  [3] evaluate_dimensionality_reduction(dims_list::Vector{Int64}, data_sources::Dict{String, Matrix{Float64}}, methods::Vector{String}, repeats::Int64, clustering_methods::Vector{String}, vae_results::Dict{Any, Any}, group_array::Vector{Int64}, select_counts::Vector{Int64})
#
#    @ Main g:\Lyubov\TNM_project\utils_clustering.jl:348
#
#  [4] top-level scope
#
#    @ g:\Lyubov\TNM_project\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:1
